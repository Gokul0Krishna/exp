# %% [markdown]
# <a href="https://colab.research.google.com/github/Gokul0Krishna/exp/blob/main/testsite5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip "/content/Basketball Players.v25i.yolov5pytorch.zip"
# Out:
# Archive:  /content/Basketball Players.v25i.yolov5pytorch.zip
#   inflating: README.dataset.txt
#   inflating: README.roboflow.txt
#   inflating: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/Iowa_Nebraska-2023-03-06-college-men_mp4-106_jpg.rf.79d51e389b9be09c4c61962a3d7d2bf5.jpg
#  extracting: test/images/Iowa_Nebraska-2023-03-06-college-men_mp4-124_jpg.rf.3a1457970781f145f7a934dbe3ed8505.jpg
#  extracting: test/images/Iowa_Nebraska-2023-03-06-college-men_mp4-97_jpg.rf.ccd940ef5184818618f5eb8acf148d0e.jpg
#  extracting: test/images/youtube-0_jpg.rf.bf96035e61980ed07b742dbc9c775d6e.jpg
#  extracting: test/images/youtube-114_jpg.rf.787942845ad252db4f8047fe9c46811a.jpg
#  extracting: test/images/youtube-128_jpg.rf.9c69a0f24eb15649f6d5bd2f1a9d47a2.jpg
#  extracting: test/images/youtube-137_jpg.rf.2a8f75e3ab665707e731d5c6c0aca9a8.jpg
#  extracting: test/images/youtube-13_jpg.rf.5ab50e950c485a5a9eb269719829f4cb.jpg
#  extracting: test/images/youtube-151_jpg.rf.f205a179401b344793163573eafd358d.jpg
#  extracting: test/images/youtube-153_jpg.rf.83ebeca4314e66b16680055bb025b646.jpg
#  extracting: test/images/youtube-15_jpg.rf.22a08fb220872e38ed069f28024679e0.jpg
#  extracting: test/images/youtube-161_jpg.rf.ee68abc540e39d4eefaaf82837b48fa5.jpg
#  extracting: test/images/youtube-186_jpg.rf.e34b5d224ac0500856d443efb61e5c5b.jpg
#  extracting: test/images/youtube-18_jpg.rf.ed24dfbee80f1a3aac9b37f7a6cae73d.jpg
#  extracting: test/images/youtube-201_jpg.rf.bcdfaf999ec94ef026dfcee1af55fe61.jpg
#  extracting: test/images/youtube-230_jpg.rf.798254e982f3508f3013d75a247488a0.jpg
#  extracting: test/images/youtube-23_jpg.rf.1493b1c9d052156108bd07050767dd55.jpg
#  extracting: test/images/youtube-29_jpg.rf.6905847362499845776748c4e8f8acaf.jpg
#  extracting: test/images/youtube-2_jpg.rf.d29259f72c95f3709ff4a5abf1de7a58.jpg
#  extracting: test/images/youtube-47_jpg.rf.d3caa65acedcaa6030e22b2a15a75acb.jpg
#  extracting: test/images/youtube-48_jpg.rf.a431688cd35b0d4b5051fc72122b96e7.jpg
#  extracting: test/images/youtube-65_jpg.rf.f335c3136b7f6e770b886b99e3c5a6c6.jpg
#  extracting: test/images/youtube-70_jpg.rf.341736ab7c88403d4bf9901db61056b6.jpg
#  extracting: test/images/youtube-9_jpg.rf.6371f42773a65ba636fdbd61c48ffd98.jpg
#    creating: test/labels/
#   inflating: test/labels/Iowa_Nebraska-2023-03-06-college-men_mp4-106_jpg.rf.79d51e389b9be09c4c61962a3d7d2bf5.txt
#   inflating: test/labels/Iowa_Nebraska-2023-03-06-college-men_mp4-124_jpg.rf.3a1457970781f145f7a934dbe3ed8505.txt
#  extracting: train/images/youtube-102_jpg.rf.edd10105bac00efb5544e9d4bd55e203.jpg
#  extracting: train/images/youtube-104_jpg.rf.0c90cdf13197ddfea26ce49856c1cf75.jpg
#  extracting: train/images/youtube-104_jpg.rf.18f53c19b7a99518273bdc155eb61c53.jpg
#  extracting: train/images/youtube-104_jpg.rf.20712341422f5d1b97a05e3b2a3bf584.jpg
#  extracting: train/images/youtube-104_jpg.rf.67420ad4944638a05e7a223bf67de4ba.jpg
#  extracting: train/images/youtube-104_jpg.rf.7ec1e50a0eb438cd428b10b417db0c69.jpg
#  extracting: train/images/youtube-104_jpg.rf.85acdf5c169de4aee2195beef07283c1.jpg
#  extracting: train/images/youtube-104_jpg.rf.8e52665a6fc09a5c47a62012148d6a80.jpg
#  extracting: train/images/youtube-104_jpg.rf.a3004bc6f8c7b4871c93d0f051afa060.jpg
#  extracting: train/images/youtube-104_jpg.rf.a35b1d555fdf9821903b49313d25841b.jpg
#  extracting: train/images/youtube-104_jpg.rf.a4f3576eb92f85ecc919f9bf7d7fd31c.jpg
#  extracting: train/images/youtube-108_jpg.rf.0734ab76e84faac5735bed394cb49ec7.jpg
#  extracting: train/images/youtube-108_jpg.rf.11853bf6182e78099591ce084220838b.jpg
#  extracting: train/images/youtube-108_jpg.rf.5ce397e695c19a51da5248f46258cd83.jpg
#  extracting: train/images/youtube-108_jpg.rf.5f218cbc3c5801448a5412e757f8e379.jpg
#  extracting: train/images/youtube-108_jpg.rf.70b716c032a71897f1ebddd7813535d7.jpg
#  extracting: train/images/youtube-108_jpg.rf.b0ab05eeb5049d98d4a1f151db8f070f.jpg
#  extracting: train/images/youtube-108_jpg.rf.c322dd10194fbc1c6b2bd65a376a1ffe.jpg
#  extracting: train/images/youtube-108_jpg.rf.d7d35cd21d29421708ddb142b69a71bd.jpg
#  extracting: train/images/youtube-108_jpg.rf.f6d16dc8d95bc9daeffc04926fa09c83.jpg
#  extracting: train/images/youtube-108_jpg.rf.feeb587328d2475828e8e8b7dfc85389.jpg
#  extracting: train/images/youtube-109_jpg.rf.00718ac18fca9c72b17e7499af73c3d3.jpg
#  extracting: train/images/youtube-109_jpg.rf.1d0d287399f6135e87dafcb913201007.jpg
#  extracting: train/images/youtube-109_jpg.rf.2bfc9692e42383ed43bd708242f4dd99.jpg
#  extracting: train/images/youtube-109_jpg.rf.2d5b8f2e09954fa738fbaa434a5cc0e9.jpg
#  extracting: train/images/youtube-109_jpg.rf.3fefdec49cfbad0aee671e466e5a0fb5.jpg
#  extracting: train/images/youtube-109_jpg.rf.8042ac5cd0454d9c9003a3d734ed11be.jpg
#  extracting: train/images/youtube-109_jpg.rf.80c6a1692f41aa1b0fdd98a38ffa38dd.jpg
#  extracting: train/images/youtube-109_jpg.rf.a588643e16a2b81b23210b30a1d8582a.jpg
#  extracting: train/images/youtube-109_jpg.rf.e7c3a1722f6ebe2d073d2f200d5d3ec1.jpg
#  extracting: train/images/youtube-109_jpg.rf.f0dc12548112743d30fce64affbf5a39.jpg
#  extracting: train/images/youtube-10_jpg.rf.0e914289e7b5fafa26054e6be0eaa2ff.jpg
#  extracting: train/images/youtube-10_jpg.rf.6377c429918f3cd0f23cadf7d87c7218.jpg
#  extracting: train/images/youtube-10_jpg.rf.72b84a193627e69de29147fa352f2922.jpg
#  extracting: train/images/youtube-10_jpg.rf.7b47c82cc821122a2855efd45e2676cf.jpg
#  extracting: train/images/youtube-10_jpg.rf.7b7750d30e320fea368e7f0c4a0a75e1.jpg
#  extracting: train/images/youtube-10_jpg.rf.a5a5643b98a781e44786976b413e55b1.jpg
#  extracting: train/images/youtube-10_jpg.rf.af44babc8f8de9eb1ecfc5ddbc4e0f68.jpg
#  extracting: train/images/youtube-10_jpg.rf.be99d79724425a10027c74e08e3ef609.jpg
#  extracting: train/images/youtube-10_jpg.rf.d1957bf673e251e6a10d2d0f8dff3d8f.jpg
#  extracting: train/images/youtube-10_jpg.rf.e1032c1a3f604975f4b8aa7aa525cf70.jpg
#  extracting: train/images/youtube-117_jpg.rf.00efdd1180b37574e29b3964d322c925.jpg
#  extracting: train/images/youtube-117_jpg.rf.12d0e0fc2c3f8eb89110d39856fc62e4.jpg
#  extracting: train/images/youtube-117_jpg.rf.317e345d5218b76d6f8cf85b95a9a1f6.jpg
#  extracting: train/images/youtube-117_jpg.rf.581407ea83d4213581ceb63bb3831413.jpg
#  extracting: train/images/youtube-117_jpg.rf.827b8c1541be8a7d603e246217bb91bc.jpg
#  extracting: train/images/youtube-117_jpg.rf.8b29a29159a39d104a98ddeb12734ca2.jpg
#  extracting: train/images/youtube-117_jpg.rf.a5542f59f9cd307058a505be1fd89008.jpg
#  extracting: train/images/youtube-117_jpg.rf.ac0760d8b2597739c5435fbdde8acdfd.jpg
#  extracting: train/images/youtube-117_jpg.rf.b03e43a9115b0d82ec11af3f470f7884.jpg
#  extracting: train/images/youtube-117_jpg.rf.dab0007afa2cbd033e8818e076d8a996.jpg
#  extracting: train/images/youtube-120_jpg.rf.04dadc5021a671dbbfd8090714b7fd65.jpg
#  extracting: train/images/youtube-120_jpg.rf.0d0d4f179c2b6bca6971459172b83191.jpg
#  extracting: train/images/youtube-120_jpg.rf.1be42b340e587daa9d11e6da14adf514.jpg
#  extracting: train/images/youtube-120_jpg.rf.2287094df521a497c9d7d199dd21581e.jpg
#  extracting: train/images/youtube-120_jpg.rf.2fb7107ea9d38e059e9ae649f29a0a25.jpg
#  extracting: train/images/youtube-120_jpg.rf.55fa2aa05f39de495ab0ef60386123e1.jpg
#  extracting: train/images/youtube-120_jpg.rf.703571ea798e72a9d6b74eb4776d2c08.jpg
#  extracting: train/images/youtube-120_jpg.rf.718869795fd090fecef48b5639badebe.jpg
#  extracting: train/images/youtube-120_jpg.rf.89e4dc20c14bc5e09cd70b4b030caccf.jpg
#  extracting: train/images/youtube-120_jpg.rf.8b2062ef5a7561136100f050bb05e2e4.jpg
#  extracting: train/images/youtube-120_jpg.rf.8f3151aebd477f3b50525b339b0da0d9.jpg
#  extracting: train/images/youtube-120_jpg.rf.940185a8bb49bdfc913068b355eaaf8b.jpg
#  extracting: train/images/youtube-120_jpg.rf.9c11167d3ba9b28739eccc89083884bc.jpg
#  extracting: train/images/youtube-120_jpg.rf.a5f8f4f29f07bb1d813f31708f345c3c.jpg
#  extracting: train/images/youtube-120_jpg.rf.a74edcda72092fd82d81e4e3bb01193e.jpg
#  extracting: train/images/youtube-120_jpg.rf.b1b3835a3e098f1f5ff2c41cacec5e4c.jpg
#  extracting: train/images/youtube-120_jpg.rf.b2b3b1d0749abba6a8e21865bedfc893.jpg
#  extracting: train/images/youtube-120_jpg.rf.b949227820cd46ad17379cc9bc67ba05.jpg
#  extracting: train/images/youtube-120_jpg.rf.bc15c814f0bfe4e00f38f9a556f69d1c.jpg
#  extracting: train/images/youtube-120_jpg.rf.ffca3d34c2abdd2aaea50f417f755c56.jpg
#  extracting: train/images/youtube-121_jpg.rf.13920075e93b5ebe2b3f9e47b8109526.jpg
#  extracting: train/images/youtube-121_jpg.rf.36ad3991245440b9a2e5b9ef92425344.jpg
#  extracting: train/images/youtube-121_jpg.rf.36eadb4d4d40c21b93589f6616ed435a.jpg
#  extracting: train/images/youtube-121_jpg.rf.956de2fd63f1f9bfc010234f9cc3cbea.jpg
#  extracting: train/images/youtube-121_jpg.rf.c51df52e3b0f7ba4867177696c6838ec.jpg
#  extracting: train/images/youtube-121_jpg.rf.ca6092ebca53577fc0473abbc688bffb.jpg
#  extracting: train/images/youtube-121_jpg.rf.d757af7c0b149601f5cc9edf50467eff.jpg
#  extracting: train/images/youtube-121_jpg.rf.df621bba340b2bc6d501f647e5a3a7e0.jpg
#  extracting: train/images/youtube-121_jpg.rf.e3507e5090a9cd0a088c6b26b6ef12bf.jpg
#  extracting: train/images/youtube-121_jpg.rf.ed3c32037da1d2a5e7ea2b42f92a1e1e.jpg
#  extracting: train/images/youtube-124_jpg.rf.029a3c1dbc05c65824f061462557e433.jpg
#  extracting: train/images/youtube-124_jpg.rf.11918ebae6a7e127190d55df4e604517.jpg
#  extracting: train/images/youtube-124_jpg.rf.2e536f2bbe99c340698cd2ca2d6ccf70.jpg
#  extracting: train/images/youtube-124_jpg.rf.6433c5dddd76778d907e5de3083c0964.jpg
#  extracting: train/images/youtube-124_jpg.rf.6e7387a1e830e1172649ebf5eaccb4ba.jpg
#  extracting: train/images/youtube-124_jpg.rf.c36c8e6d7565b16deef80f1d5e465bb1.jpg
#  extracting: train/images/youtube-124_jpg.rf.cb7cc37fc0ff43faff15eaa7b0c93d45.jpg
#  extracting: train/images/youtube-124_jpg.rf.db31e85b95d55c22cb2239d097e778b8.jpg
#  extracting: train/images/youtube-124_jpg.rf.e1623b81d3784e3776839bab0787b9d5.jpg
#  extracting: train/images/youtube-124_jpg.rf.f06cb64db8a31da3932323fc26d45891.jpg
#  extracting: train/images/youtube-128_jpg.rf.1a9c57510d093c5f0b80236dae5a97dc.jpg
#  extracting: train/images/youtube-128_jpg.rf.5166597ec0b7faa0a71b78bc725856d8.jpg
#  extracting: train/images/youtube-128_jpg.rf.763c764e5df105ba8ba28885c85f41de.jpg
#  extracting: train/images/youtube-128_jpg.rf.7b37d1e0fa65be390aad3c14e56675db.jpg
#  extracting: train/images/youtube-128_jpg.rf.83807aaf90927f9ae7fb809f681f1f52.jpg
#  extracting: train/images/youtube-128_jpg.rf.866a83c63177b7c2b012074623a1e1d2.jpg
#  extracting: train/images/youtube-128_jpg.rf.c1087b887e74bdb6a8ba9c977840f2be.jpg
#  extracting: train/images/youtube-128_jpg.rf.e143b0efd49a42ae6fe74e7212fa25f6.jpg
#  extracting: train/images/youtube-128_jpg.rf.e6efa6e1b30a54d30a4c87afe71eff9f.jpg
#  extracting: train/images/youtube-128_jpg.rf.eb7fbad7856ccefd7529e4665149bbab.jpg
#  extracting: train/images/youtube-12_jpg.rf.048e6272beb601871718a582892148c1.jpg
#  extracting: train/images/youtube-12_jpg.rf.0af0feaf71d8b2eec0e47230cd46e9e2.jpg
#  extracting: train/images/youtube-12_jpg.rf.123e5c489b16679a5deaf79c730af6c1.jpg
#  extracting: train/images/youtube-12_jpg.rf.1a09848839b85712ebeca4fa346de903.jpg
#  extracting: train/images/youtube-12_jpg.rf.1aadc29a9ccf704e91f660ede8a9b3d1.jpg
#  extracting: train/images/youtube-12_jpg.rf.271a9016731973d2222021c38b71eee2.jpg
#  extracting: train/images/youtube-12_jpg.rf.2bfc6e2d4e42e74535254361c3638af0.jpg
#  extracting: train/images/youtube-12_jpg.rf.2c77155c9eb2a218a2aef20436814125.jpg
#  extracting: train/images/youtube-12_jpg.rf.702a2d6f26f56dfe9a722b947d525d61.jpg
#  extracting: train/images/youtube-12_jpg.rf.76c3025404ca9bc03322a43e103d4dc8.jpg
#  extracting: train/images/youtube-12_jpg.rf.7d78090f16d4cdb028ec11b5e70928a8.jpg
#  extracting: train/images/youtube-12_jpg.rf.b4a3d1a38963008dade3fb3a9121eeae.jpg
#  extracting: train/images/youtube-12_jpg.rf.bb885f2778151234c6da33ba646b740c.jpg
#  extracting: train/images/youtube-12_jpg.rf.c5ae70ccf9fabd8ff00f6ab547f84fa3.jpg
#  extracting: train/images/youtube-12_jpg.rf.daea53b3a9714f06c21ab176918fbd0f.jpg
#  extracting: train/images/youtube-12_jpg.rf.ddbc0398ee0614772c44bd5175398372.jpg
#  extracting: train/images/youtube-12_jpg.rf.e34bb27a84a1422d033eef9383cf913b.jpg
#  extracting: train/images/youtube-12_jpg.rf.eab80ea10fc155832fb102bfcaf92ed9.jpg
#  extracting: train/images/youtube-12_jpg.rf.f68f0c1934f8e8e333163a2e4a534c4e.jpg
#  extracting: train/images/youtube-12_jpg.rf.fe270ae9c7f6191a13ffa1bc25ffd12c.jpg
#  extracting: train/images/youtube-131_jpg.rf.00ecc4593a898d5c655bd7d99163fbde.jpg
#  extracting: train/images/youtube-131_jpg.rf.202837680e957e671fa8eeda13e155eb.jpg
#  extracting: train/images/youtube-131_jpg.rf.2abf2262cd3b9492dba156099aebb49d.jpg
#  extracting: train/images/youtube-131_jpg.rf.33b5139097473425faa39d8646d7a73a.jpg
#  extracting: train/images/youtube-131_jpg.rf.45da104f21a29da6e68096daeb756261.jpg
#  extracting: train/images/youtube-131_jpg.rf.53b7f96655fc0882a3f139c9a21de499.jpg
#  extracting: train/images/youtube-131_jpg.rf.542716bd3fa753b9ec67d6dde34c10e5.jpg
#  extracting: train/images/youtube-131_jpg.rf.c22616114cfc49b294846c907e2698e7.jpg
#  extracting: train/images/youtube-131_jpg.rf.d64a5a6670eb1cd9616377dd11a28945.jpg
#  extracting: train/images/youtube-131_jpg.rf.ebcb5a37ec583477a5ed5e96ad390009.jpg
#  extracting: train/images/youtube-136_jpg.rf.271e2b9ededed3cca4a75edfb99af12b.jpg
#  extracting: train/images/youtube-136_jpg.rf.447e6942aa79e685dacca57cc850813c.jpg
#  extracting: train/images/youtube-136_jpg.rf.4d44f68371ea09f0387786df92263637.jpg
#  extracting: train/images/youtube-136_jpg.rf.50065930f7d7d524f8bbcf47e861d46f.jpg
#  extracting: train/images/youtube-136_jpg.rf.54e8f5776bc6477fb930890163ad555b.jpg
#  extracting: train/images/youtube-136_jpg.rf.6fedf1ac1f1dacdb8a52ac7f270e81ab.jpg
#  extracting: train/images/youtube-136_jpg.rf.7fc670d231eca7f83ca75fdca4dcecba.jpg
#  extracting: train/images/youtube-136_jpg.rf.8ce01a6a56d1d75cb98b2a2c38d89061.jpg
#  extracting: train/images/youtube-136_jpg.rf.de941537153eb0011c03ae045d18bd63.jpg
#  extracting: train/images/youtube-136_jpg.rf.f020c975bb843bd4c0bfbd125848e75a.jpg
#  extracting: train/images/youtube-139_jpg.rf.167ed2cc50f4aef37f86d6765b36c7b3.jpg
#  extracting: train/images/youtube-139_jpg.rf.203968e25362cbb63d5edef1ce8e10fe.jpg
#  extracting: train/images/youtube-139_jpg.rf.65597916691219d6cf331b66864c36f4.jpg
#  extracting: train/images/youtube-139_jpg.rf.6ef6cf5d880db5d433f40ea9f83e0213.jpg
#  extracting: train/images/youtube-139_jpg.rf.77d08d6c644a33aaa32e497fbc081dd8.jpg
#  extracting: train/images/youtube-139_jpg.rf.8b8f1d0b8e4d632ad30d9e8696073123.jpg
#  extracting: train/images/youtube-139_jpg.rf.8db5906b6f84248adda7a55d553105ad.jpg
#  extracting: train/images/youtube-139_jpg.rf.9eba0bc601f802719e21fd8739345c97.jpg
#  extracting: train/images/youtube-139_jpg.rf.a58f0703fdd09d3f33fc6df904c98166.jpg
#  extracting: train/images/youtube-139_jpg.rf.ed3ab22452e3106bf4221902267135b9.jpg
#  extracting: train/images/youtube-13_jpg.rf.07d5a78b53944cfb9a21457c065f5f6a.jpg
#  extracting: train/images/youtube-13_jpg.rf.0bd42a8c9476b32e4984f9f8d056fa06.jpg
#  extracting: train/images/youtube-13_jpg.rf.2a78c1459b71278a91625b8c6396c06b.jpg
#  extracting: train/images/youtube-13_jpg.rf.3ec3bc96cc30d3d83cd1bdbe5bcc14f2.jpg
#  extracting: train/images/youtube-13_jpg.rf.54e320d75ca249e62fb934959717541b.jpg
#  extracting: train/images/youtube-13_jpg.rf.558e8f9d591be2767ff289a1728b7a03.jpg
#  extracting: train/images/youtube-13_jpg.rf.657f0981b452c23bfe10aa95ee1c3d29.jpg
#  extracting: train/images/youtube-13_jpg.rf.809259da388f9418d2bad89cab067a46.jpg
#  extracting: train/images/youtube-13_jpg.rf.8b421448e13150cbee2d28b4198e716a.jpg
#  extracting: train/images/youtube-13_jpg.rf.f375a69bcb78e689e8de97ba47f342b0.jpg
#  extracting: train/images/youtube-145_jpg.rf.019673f8a6794fa7ca6be11b97a03f11.jpg
#  extracting: train/images/youtube-145_jpg.rf.10a287d6b464a21abf49b54de8b4b148.jpg
#  extracting: train/images/youtube-145_jpg.rf.13bdc0aceb2f8f5ad35d3c681ebb8a02.jpg
#  extracting: train/images/youtube-145_jpg.rf.191dc2840553a07e3097bdff76a07b9b.jpg
#  extracting: train/images/youtube-145_jpg.rf.1c1a5972eb2e65d0ab492746d79152b6.jpg
#  extracting: train/images/youtube-145_jpg.rf.298d453f8f78bab07d7cbbee0c49f69f.jpg
#  extracting: train/images/youtube-145_jpg.rf.3ed6eb791115d8eb105e48e23c86fdba.jpg
#  extracting: train/images/youtube-145_jpg.rf.4798061384af17ae5be88613a276aa82.jpg
#  extracting: train/images/youtube-145_jpg.rf.54ebc6462582c1c649e999465d8e9a67.jpg
#  extracting: train/images/youtube-145_jpg.rf.601be0eb1aaf64c1bc1fb1068b474620.jpg
#  extracting: train/images/youtube-145_jpg.rf.62fa5f3e541f66ccbae65a84f8fb8426.jpg
#  extracting: train/images/youtube-145_jpg.rf.77c0be05d319136a610e14c5e20eeb49.jpg
#  extracting: train/images/youtube-145_jpg.rf.a4a6e7b5b4cc93642dab3544e7b5ab7d.jpg
#  extracting: train/images/youtube-145_jpg.rf.bc595ad9769983bc0fd8b6a47eb7cb26.jpg
#  extracting: train/images/youtube-145_jpg.rf.bd43643342067dd05bf8dc6a13bb787f.jpg
#  extracting: train/images/youtube-145_jpg.rf.c1714385e3bf473873d94440e99411e7.jpg
#  extracting: train/images/youtube-145_jpg.rf.d09a86c9266d2b3f905fc6c15149222c.jpg
#  extracting: train/images/youtube-145_jpg.rf.d12f600b8a329dbc3cb9068c0d8899bf.jpg
#  extracting: train/images/youtube-145_jpg.rf.d5c4fd5c201ae3e7333e6fb59c44a5f7.jpg
#  extracting: train/images/youtube-145_jpg.rf.dc8217d15b078d36426435b890665986.jpg
#  extracting: train/images/youtube-148_jpg.rf.182a181a42c9b857ab0da5400c48e543.jpg
#  extracting: train/images/youtube-148_jpg.rf.4a824a67a9d17450c6038f51a0e40d61.jpg
#  extracting: train/images/youtube-148_jpg.rf.77fef9c50eb7c6bb6f63130a0040e051.jpg
#  extracting: train/images/youtube-148_jpg.rf.9c6727732e6921ac41f494ab586bc48b.jpg
#  extracting: train/images/youtube-148_jpg.rf.a53f7fad8ab9b4a1caa8447cf4a12240.jpg
#  extracting: train/images/youtube-148_jpg.rf.b152925afaa75eb4128910ae11faa9c7.jpg
#  extracting: train/images/youtube-148_jpg.rf.c54ab018582905387b33656071896c6a.jpg
#  extracting: train/images/youtube-148_jpg.rf.d3e94516caa206e2651824931c901d3c.jpg
#  extracting: train/images/youtube-148_jpg.rf.d5f25614af9dcbe3ed282243a4cd6f46.jpg
#  extracting: train/images/youtube-148_jpg.rf.f11c067fc30a1d6271a24f5f923b0c29.jpg
#  extracting: train/images/youtube-152_jpg.rf.01b07773e4a45499a81505dc9f94f7f1.jpg
#  extracting: train/images/youtube-152_jpg.rf.0ad196fdfe4efc12e6cfc447ac699db5.jpg
#  extracting: train/images/youtube-152_jpg.rf.1926cc0a5e60f557e5ffeb473c31abdd.jpg
#  extracting: train/images/youtube-152_jpg.rf.555a77a477d20ba4b5d49a058badc9c9.jpg
#  extracting: train/images/youtube-152_jpg.rf.64e97056deeaea7a8e8a6edd77c6ac53.jpg
#  extracting: train/images/youtube-152_jpg.rf.661496231749e1f47a9abdd62025e3d2.jpg
#  extracting: train/images/youtube-152_jpg.rf.90984570f4f74057a11d5e0536ff0e90.jpg
#  extracting: train/images/youtube-152_jpg.rf.962c772db185e7251cf6337285612ffa.jpg
#  extracting: train/images/youtube-152_jpg.rf.c27a7536face7b01bfe83068ab55e7cc.jpg
#  extracting: train/images/youtube-152_jpg.rf.d01ecfa0aef9667779b051688586dec7.jpg
#  extracting: train/images/youtube-153_jpg.rf.22bc196de7a92b79c147a9d4a2b11437.jpg
#  extracting: train/images/youtube-153_jpg.rf.23f522600a6418b40c3b647c32cb859a.jpg
#  extracting: train/images/youtube-153_jpg.rf.390d77ce45777d070b4022591ad476d0.jpg
#  extracting: train/images/youtube-153_jpg.rf.565c6bce371013c7f140096a851e3af7.jpg
#  extracting: train/images/youtube-153_jpg.rf.880af691e75abefcf8c86fc77d63a633.jpg
#  extracting: train/images/youtube-153_jpg.rf.96075eda6e4f9ecaf2040e90964676fd.jpg
#  extracting: train/images/youtube-153_jpg.rf.9a5affa5a7abedc9cb8be4e408b0a94e.jpg
#  extracting: train/images/youtube-153_jpg.rf.b37fa1d4e3c26d6d700bd881b857512f.jpg
#  extracting: train/images/youtube-153_jpg.rf.c492500e83240421b8ff4b9430b50f84.jpg
#  extracting: train/images/youtube-153_jpg.rf.ee48ec8c789fd32d3e0f2d0c6aa4e2ed.jpg
#  extracting: train/images/youtube-159_jpg.rf.28569d7928b5902a674db1ce1d7cf32e.jpg
#  extracting: train/images/youtube-159_jpg.rf.406eb487fcdd481e907fbc1d633657ab.jpg
#  extracting: train/images/youtube-159_jpg.rf.4474b956e13e32bdab6a15738a5f6372.jpg
#  extracting: train/images/youtube-159_jpg.rf.48e5f0ba3e1a1aab7896912b63185a87.jpg
#  extracting: train/images/youtube-159_jpg.rf.6419d90540badceb9b21803efad786a1.jpg
#  extracting: train/images/youtube-159_jpg.rf.67c0649a4ce5de9b84251a4750acc3ed.jpg
#  extracting: train/images/youtube-159_jpg.rf.99788bb9285fc2b97be44a51fa28f61c.jpg
#  extracting: train/images/youtube-159_jpg.rf.c2609f6ec6cb4b8bc41969ee210bfeaf.jpg
#  extracting: train/images/youtube-159_jpg.rf.d3bbd1fba134f3448b6ff7663ee02d37.jpg
#  extracting: train/images/youtube-159_jpg.rf.e06239c76b1474eca3aa7c0778a2177d.jpg
#  extracting: train/images/youtube-15_jpg.rf.142dbdea5ff25ba027cb026cae4d848b.jpg
#  extracting: train/images/youtube-15_jpg.rf.4b50d3f4ed5d442b0908d2b3ae12bf88.jpg
#  extracting: train/images/youtube-15_jpg.rf.5cda59a6f6a487ce155f606360990a7b.jpg
#  extracting: train/images/youtube-15_jpg.rf.83cc4e49f5e98836fff5e62dc183be23.jpg
#  extracting: train/images/youtube-15_jpg.rf.86f5d7cd5824717b35d7ec20ccf15842.jpg
#  extracting: train/images/youtube-15_jpg.rf.87d32b9ba5ace312bc6f00a85620cc87.jpg
#  extracting: train/images/youtube-15_jpg.rf.a74cb674d25933c4b71f4b97dd7e9725.jpg
#  extracting: train/images/youtube-15_jpg.rf.c4df7556141fd502210b0a2509909d81.jpg
#  extracting: train/images/youtube-15_jpg.rf.cd2e189831c61d1241f4ad8bf11bab7e.jpg
#  extracting: train/images/youtube-15_jpg.rf.f82e498a9c96b9748f708d1445d5f459.jpg
#  extracting: train/images/youtube-163_jpg.rf.0bfc7703e5d1179cd4453ed1ee617173.jpg
#  extracting: train/images/youtube-163_jpg.rf.1c3c993f94e00fcc6c715b8e3b8a4cd4.jpg
#  extracting: train/images/youtube-163_jpg.rf.2aec4e57d16b6d7173f1a899e8049936.jpg
#  extracting: train/images/youtube-163_jpg.rf.625583210fcc333226839672dec0919f.jpg
#  extracting: train/images/youtube-163_jpg.rf.9313cb8aea9e944de2766dc6d2e5a2fa.jpg
#  extracting: train/images/youtube-163_jpg.rf.b6fc536bc67a7ffcbc145589ddd95e6f.jpg
#  extracting: train/images/youtube-163_jpg.rf.d96e567a87a8a280ab7777b0afe4cc15.jpg
#  extracting: train/images/youtube-163_jpg.rf.e4b90d0848c989c7699413aaa4fc285e.jpg
#  extracting: train/images/youtube-163_jpg.rf.f3e0e1ed98f0581cb4e4340c2da34487.jpg
#  extracting: train/images/youtube-163_jpg.rf.f6590bf3b0b735c593d48bdc1e18ca7e.jpg
#  extracting: train/images/youtube-164_jpg.rf.0d59390ae9a1f9a9244e2461a205418b.jpg
#  extracting: train/images/youtube-164_jpg.rf.3dd1b0b994e68b47d70f9af0ddc5ab35.jpg
#  extracting: train/images/youtube-164_jpg.rf.44a5f64c499136dd530d4f6292711ecc.jpg
#  extracting: train/images/youtube-164_jpg.rf.8020528a1e8cff62e8df89d84f8b0e9c.jpg
#  extracting: train/images/youtube-164_jpg.rf.86be2bd0a81e5cb276fd034a42be05c5.jpg
#  extracting: train/images/youtube-164_jpg.rf.afde3a67f3a9b11292631a0a76967ecc.jpg
#  extracting: train/images/youtube-164_jpg.rf.b9b8e49359c98916b9e51778fb6967f5.jpg
#  extracting: train/images/youtube-164_jpg.rf.c2ff929814793f95d3472b0e77d6aec8.jpg
#  extracting: train/images/youtube-164_jpg.rf.d36fb1c710e1f0913682dfee42d943c7.jpg
#  extracting: train/images/youtube-164_jpg.rf.ec848eb3da00ff87579d6a0fec398aa3.jpg
#  extracting: train/images/youtube-16_jpg.rf.012c85f85f108615d66326ed5c3e1922.jpg
#  extracting: train/images/youtube-16_jpg.rf.3ed3dc0e577e966ae6404b7790eb5f7b.jpg
#  extracting: train/images/youtube-16_jpg.rf.658c5c086684cf62f3e26f8bf41a3ebd.jpg
#  extracting: train/images/youtube-16_jpg.rf.71cd89fb9e90f58d19577cd528fad759.jpg
#  extracting: train/images/youtube-16_jpg.rf.87b6dbf40aa69fab59d406c0c5425ca2.jpg
#  extracting: train/images/youtube-16_jpg.rf.a8e77a71a4181c27b772838fb243be53.jpg
#  extracting: train/images/youtube-16_jpg.rf.b42e134c6d4edcd5adc832b2fa870ed9.jpg
#  extracting: train/images/youtube-16_jpg.rf.b568ff1c17c0e201a82786e06292d1a3.jpg
#  extracting: train/images/youtube-16_jpg.rf.d374510f72b36f3e2573e05e04525494.jpg
#  extracting: train/images/youtube-16_jpg.rf.d6d259b3c34e9b0aa31cdee1d3de4f67.jpg
#  extracting: train/images/youtube-172_jpg.rf.204e88ec819e8edd9a246c74d1fd64e3.jpg
#  extracting: train/images/youtube-172_jpg.rf.2e19bd14f610f3dd9c0f40cb72f69158.jpg
#  extracting: train/images/youtube-172_jpg.rf.3348da3cfc7aea9bc016cb66f11a56f8.jpg
#  extracting: train/images/youtube-172_jpg.rf.3dbc436b6b481c2ce726e1aa065b3c04.jpg
#  extracting: train/images/youtube-172_jpg.rf.4270cbc558668ad2eb79509c95a8ae5f.jpg
#  extracting: train/images/youtube-172_jpg.rf.53f2925c307e4e656da9c966eb9df5ce.jpg
#  extracting: train/images/youtube-172_jpg.rf.8d60b8e64bc75554f7462e7ce9cbf870.jpg
#  extracting: train/images/youtube-172_jpg.rf.db8c5466de1671c17000cb79ecbf97d5.jpg
#  extracting: train/images/youtube-172_jpg.rf.dbf485968ee9af29c8616842ac53c751.jpg
#  extracting: train/images/youtube-172_jpg.rf.ddd8058ea43e6fc4920244c3799413ab.jpg
#  extracting: train/images/youtube-176_jpg.rf.0175cdbb0db821348e4f994ede591628.jpg
#  extracting: train/images/youtube-176_jpg.rf.13518429d92b2d9ded5a80c89796a9ca.jpg
#  extracting: train/images/youtube-176_jpg.rf.148c34ee188a967f7619f6a190e26be7.jpg
#  extracting: train/images/youtube-176_jpg.rf.2c9098d44bf7e386f2e3a7f1192ea516.jpg
#  extracting: train/images/youtube-176_jpg.rf.5bfd5fc29d2bfd824306a013e51e53e7.jpg
#  extracting: train/images/youtube-176_jpg.rf.742438a633ca50f3b041f12a3ba7da10.jpg
#  extracting: train/images/youtube-176_jpg.rf.c6543ff89031ba409d36374398b8d3d0.jpg
txt
#    creating: valid/
#    creating: valid/images/
#  extracting: valid/images/Iowa_Nebraska-2023-03-06-college-men_mp4-121_jpg.rf.acdf100e399a27167870bdbcaad27182.jpg
#  extracting: valid/images/Iowa_Nebraska-2023-03-06-college-men_mp4-14_jpg.rf.44c69150d25e4e75527ec10c1ac5fe05.jpg
#  extracting: valid/images/Iowa_Nebraska-2023-03-06-college-men_mp4-17_jpg.rf.4b218abc66eaa5cf03a84b51f06f9222.jpg
#  extracting: valid/images/Iowa_Nebraska-2023-03-06-college-men_mp4-26_jpg.rf.a1fc606c68be6f41409b651cd6e50521.jpg
#  extracting: valid/images/youtube-11_jpg.rf.99bc14e3c1e11ddb052d2da8073a212d.jpg
#  extracting: valid/images/youtube-11_jpg.rf.c8319d25ab01babbfc86719e7f948fc9.jpg
#  extracting: valid/images/youtube-141_jpg.rf.710d70820635112693e471ced4df77f3.jpg
#  extracting: valid/images/youtube-146_jpg.rf.758fbd689b2a0b85cf8f93696fe7fa96.jpg
#  extracting: valid/images/youtube-158_jpg.rf.2dcdd0a0aaf1dc85e697529db3843df4.jpg
#  extracting: valid/images/youtube-162_jpg.rf.1158cc43f3d14a2e7a55a2850a38e186.jpg
#  extracting: valid/images/youtube-1_jpg.rf.a3c8abb8190f9f88c62c1cf6f5a623ad.jpg
#  extracting: valid/images/youtube-20_jpg.rf.8f8d169509e7813e2be4776e1234288c.jpg
#  extracting: valid/images/youtube-21_jpg.rf.94043dedd1fa3d297e86bd043d05e2f4.jpg
#  extracting: valid/images/youtube-29_jpg.rf.29996c63467976b558f0f5c71aef124c.jpg
#  extracting: valid/images/youtube-38_jpg.rf.d2f76e660173d831b2dd8c604ab46d07.jpg
#  extracting: valid/images/youtube-3_jpg.rf.5510431b4b06d11ca1c72c913c8f31f1.jpg
#  extracting: valid/images/youtube-44_jpg.rf.71e15194f02084df82d0ae5bf315d2b3.jpg
#  extracting: valid/images/youtube-45_jpg.rf.b1ea69beed8bffc75f63b6d8c6428e38.jpg
#  extracting: valid/images/youtube-46_jpg.rf.3398fe02d0ba67678ad20c86e4e9ab34.jpg
#  extracting: valid/images/youtube-49_jpg.rf.4e310af3c0555c11fc2ce26666e11f2d.jpg
#  extracting: valid/images/youtube-50_jpg.rf.d349ca526ca7639964f447edf7605871.jpg
#  extracting: valid/images/youtube-63_jpg.rf.f69706d9b8ed6a67588f60525ac1810a.jpg
#  extracting: valid/images/youtube-69_jpg.rf.e00ce41c5f1630006ae302097b60cab2.jpg
#  extracting: valid/images/youtube-6_jpg.rf.a3b0e249c5eccd606149cbe812300e04.jpg
#  extracting: valid/images/youtube-6_jpg.rf.bd9e99e78bc1a802d22fa14bd054e1b3.jpg
#  extracting: valid/images/youtube-74_jpg.rf.a09e78383ddbcacb0e630fb80efc5fe7.jpg
#  extracting: valid/images/youtube-77_jpg.rf.bceb1146af9d133e836a3552f3f9124b.jpg
#  extracting: valid/images/youtube-79_jpg.rf.81f90a4655b50c9939d68b1909e5dd45.jpg
#   inflating: valid/labels/youtube-6_jpg.rf.bd9e99e78bc1a802d22fa14bd054e1b3.txt
#   inflating: valid/labels/youtube-74_jpg.rf.a09e78383ddbcacb0e630fb80efc5fe7.txt
#   inflating: valid/labels/youtube-77_jpg.rf.bceb1146af9d133e836a3552f3f9124b.txt
#   inflating: valid/labels/youtube-79_jpg.rf.81f90a4655b50c9939d68b1909e5dd45.txt
#   inflating: valid/labels/youtube-86_jpg.rf.76ba86e9a185b48fd9bc2e03dbc91c14.txt
#   inflating: valid/labels/youtube-8_jpg.rf.3244bde1339ca66ba40899b08db49b77.txt
#   inflating: valid/labels/youtube-91_jpg.rf.c90e69e9ef3c2e2ccdb26181a59f7b1c.txt
#   inflating: valid/labels/youtube-95_jpg.rf.11b0580caaaf5722491da6b31152d015.txt

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17521, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 17521 (delta 9), reused 0 (delta 0), pack-reused 17497 (from 4)
# Receiving objects: 100% (17521/17521), 16.66 MiB | 23.21 MiB/s, done.
# Resolving deltas: 100% (12001/12001), done.
# /content/yolov5
# Requirement already satisfied: gitpython>=3.1.30 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 5)) (3.1.45)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (3.10.0)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (2.0.2)
# Requirement already satisfied: opencv-python>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 8)) (4.12.0.88)
# Requirement already satisfied: pillow>=10.3.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 9)) (11.3.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 10)) (5.9.5)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 11)) (6.0.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 12)) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 13)) (1.16.0)
# Collecting thop>=0.1.1 (from -r requirements.txt (line 14))
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 15)) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 16)) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 17)) (4.67.1)
# Collecting ultralytics>=8.2.64 (from -r requirements.txt (line 18))
#   Downloading ultralytics-8.3.173-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 27)) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 28)) (0.13.2)
# Requirement already satisfied: setuptools>=70.0.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 42)) (75.2.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython>=3.1.30->-r requirements.txt (line 5)) (4.0.12)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (2025.7.14)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->-r requirements.txt (line 15)) (1.3.0)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics>=8.2.64->-r requirements.txt (line 18)) (9.0.0)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics>=8.2.64->-r requirements.txt (line 18))
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2025.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements.txt (line 5)) (5.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->-r requirements.txt (line 15)) (3.0.2)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 88.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 82.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 63.8 MB/s eta 0:00:00
# Downloading ultralytics-8.3.173-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 49.8 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 thop-0.1.1.post2209072238 ultralytics-8.3.173 ultralytics-thop-2.0.14

# %%
import cv2
import numpy as np
from pathlib import Path
from yolov5.utils.general import non_max_suppression, xywh2xyxy
import matplotlib.pyplot as plt
import torch
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import torch
from models.experimental import attempt_load

# Load trained model
model = attempt_load('/content/bbplayer.pt')
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# Fusing layers...
# Model summary: 157 layers, 7034398 parameters, 0 gradients, 15.8 GFLOPs

# %%
import torch
import numpy as np
from collections import defaultdict

def iou(box1, box2):
    """Compute IoU between two boxes: [x1, y1, x2, y2]"""
    x1 = torch.max(box1[0], box2[0])
    y1 = torch.max(box1[1], box2[1])
    x2 = torch.min(box1[2], box2[2])
    y2 = torch.min(box1[3], box2[3])

    inter_area = torch.clamp(x2 - x1, min=0) * torch.clamp(y2 - y1, min=0)
    box1_area = (box1[2] - box1[0]) * (box1[3] - box1[1])
    box2_area = (box2[2] - box2[0]) * (box2[3] - box2[1])
    return inter_area / (box1_area + box2_area - inter_area + 1e-6)

def compute_ap(recall, precision):
    """Compute interpolated Average Precision (AP) using trapezoidal rule"""
    mrec = torch.cat([torch.tensor([0.]), recall, torch.tensor([1.])])
    mpre = torch.cat([torch.tensor([0.]), precision, torch.tensor([0.])])

    for i in range(mpre.numel() - 1, 0, -1):
        mpre[i - 1] = torch.max(mpre[i - 1], mpre[i])

    i = (mrec[1:] != mrec[:-1]).nonzero(as_tuple=False).squeeze()
    return torch.sum((mrec[i + 1] - mrec[i]) * mpre[i + 1])


def evaluate_detections(preds, targets, iou_thresh=0.5):
    preds = torch.tensor(preds)
    targets = torch.tensor(targets)

    # Group ground truths and predictions per class
    gt_by_class = defaultdict(list)
    pred_by_class = defaultdict(list)

    for t in targets:
        if isinstance(t, (torch.Tensor, list)) and len(t) == 1:
            t = t[0]
        if isinstance(t, torch.Tensor):
            t = t.view(-1).tolist()

        img_id, cls, x1, y1, x2, y2 = t
        img_id = int(img_id)
        cls = int(cls)
        box = torch.tensor([x1, y1, x2, y2]).float()
        gt_by_class[cls].append((img_id, box))

    for p in preds:
        if isinstance(p, (torch.Tensor, list)) and len(p) == 1:
            p = p[0]
        if isinstance(p, torch.Tensor):
            p = p.view(-1).tolist()

        img_id, cls, conf, x1, y1, x2, y2 = p
        img_id = int(img_id)
        cls = int(cls)
        conf = float(conf)
        box = torch.tensor([x1, y1, x2, y2]).float()
        pred_by_class[cls].append((img_id, conf, box))



    results = {}
    aps = []

    for cls in sorted(gt_by_class.keys()):
        gt = gt_by_class[cls]
        pred = sorted(pred_by_class.get(cls, []), key=lambda x: -x[1])  # sort by conf

        gt_used = defaultdict(set)  # img_id -> set of matched GT indices
        tp = torch.zeros(len(pred))
        fp = torch.zeros(len(pred))

        for i, (img_id, conf, pred_box) in enumerate(pred):
            gts = [b for j, b in enumerate(gt) if b[0] == img_id]
            ious = [iou(pred_box, b[1]) for b in gts] if gts else []

            if ious and max(ious) >= iou_thresh:
                max_iou_idx = int(torch.argmax(torch.tensor(ious)))
                if max_iou_idx not in gt_used[img_id]:
                    tp[i] = 1
                    gt_used[img_id].add(max_iou_idx)
                else:
                    fp[i] = 1
            else:
                fp[i] = 1

        tp_cum = torch.cumsum(tp, dim=0)
        fp_cum = torch.cumsum(fp, dim=0)
        recall = tp_cum / (len(gt) + 1e-6)
        precision = tp_cum / (tp_cum + fp_cum + 1e-6)

        ap = compute_ap(recall, precision)
        aps.append(ap)

        results[cls] = {
            "precision": precision[-1].item() if len(precision) else 0.0,
            "recall": recall[-1].item() if len(recall) else 0.0,
            "f1": (2 * precision[-1] * recall[-1] / (precision[-1] + recall[-1] + 1e-6)).item() if len(precision) else 0.0,
            "ap50": ap.item()
        }

    mAP = torch.tensor(aps).mean().item() if aps else 0.0
    return results, mAP

# %%
def load_image(path, img_size=640):
    img0 = cv2.imread(str(path))  # BGR
    img = cv2.resize(img0, (img_size, img_size))
    img = img[:, :, ::-1].transpose(2, 0, 1)  # BGR to RGB, to 3xHxW
    img = np.ascontiguousarray(img)
    img = torch.from_numpy(img).float()
    img /= 255.0
    if img.ndimension() == 3:
        img = img.unsqueeze(0)
    return img.to(device), img0

image_dir = Path('/content/test/images')
label_dir = Path('/content/test/labels')

def scale_coords(img1_shape, coords, img0_shape, ratio_pad=None):
      """Rescale coords (xyxy) from img1_shape to img0_shape"""
      if ratio_pad is None:
          # Calculate gain and pad
          gain = min(img1_shape[0] / img0_shape[0], img1_shape[1] / img0_shape[1])  # gain = old / new
          pad = (img1_shape[1] - img0_shape[1] * gain) / 2, (img1_shape[0] - img0_shape[0] * gain) / 2  # x, y
      else:
          gain = ratio_pad[0]
          pad = ratio_pad[1]

      coords[:, [0, 2]] -= pad[0]  # x padding
      coords[:, [1, 3]] -= pad[1]  # y padding
      coords[:, :4] /= gain
      coords[:, :4] = coords[:, :4].clamp(min=0)
      return coords


def pedict(img_tensor, img0, img_path, image_id):
    model.eval()
    preds_for_img = []
    targets_for_img = []

    with torch.no_grad():
        pred = model(img_tensor)[0]  # Assuming model returns (pred, ...)
        pred = non_max_suppression(pred, conf_thres=0.25, iou_thres=0.5)[0]

        if pred is not None and len(pred):
            pred[:, :4] = scale_coords(img_tensor.shape[2:], pred[:, :4], img0.shape).round()
            for *box, conf, cls in pred.tolist():
                preds_for_img.append([image_id, int(cls), conf, *box])

    # Load ground truth
    label_path = label_dir / (img_path.stem + '.txt')
    h, w = img0.shape[:2]
    if label_path.exists():
        with open(label_path, 'r') as f:
            for line in f:
                cls, xc, yc, bw, bh = map(float, line.strip().split())
                x1 = (xc - bw / 2) * w
                y1 = (yc - bh / 2) * h
                x2 = (xc + bw / 2) * w
                y2 = (yc + bh / 2) * h
                targets_for_img.append([image_id, int(cls), x1, y1, x2, y2])

    return preds_for_img, targets_for_img

# %%
from skimage.feature import local_binary_pattern
def er(image):
  grad_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=3)
  grad_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=3)
  grad_mag = np.sqrt(grad_x**2 + grad_y**2)
  return np.mean(grad_mag)

def obj_found(image):
  image = (image * 255).astype(np.uint8)
  params = cv2.SimpleBlobDetector_Params()
  params.filterByArea = True
  params.minArea = 10  # Minimum blob size (adjust for small objects)
  params.maxArea = 1000
  detector = cv2.SimpleBlobDetector_create(params)
  keypoints = detector.detect(image)
  return len(keypoints)

def ed(image):
    local_var = cv2.Laplacian(image, cv2.CV_32F).var()#The Laplacian operator highlights regions of rapid intensity change (edges),High variance = many strong edges = likely not occluded
    return local_var / (np.mean(image)+ 1e-6)

def is_blurry(image):
    return cv2.Laplacian(image, cv2.CV_64F).var()

def brightness(img):
    brightness = np.mean(img)
    return brightness

def complexity(image):
  image = np.array(image).reshape(len(image), -1)
  lbp = local_binary_pattern(image, 8, 1, method="uniform")#greater the no. more complex the image
  hist, _ = np.histogram(lbp, bins=8+2, range=(0, 8+2))
  hist = hist.astype(np.float32) / hist.sum()
  grad_mag=-np.sum(hist * np.log(hist + 1e-6))
  return grad_mag

# %%
image_id = 0
count=0
all_preds = []
all_targets = []
for img_path in image_dir.glob('*.jpg'):
        img_tensor, img0 = load_image(img_path)  # Should return a tensor [1,3,H,W] and original image
        preds, targets = pedict(img_tensor, img0, img_path, image_id)
        all_preds.append(preds)
        all_targets.append(targets)
        count+=1
        image_id += 1

all_preds_flat = [item for sublist in all_preds for item in sublist]
all_targets_flat = [item for sublist in all_targets for item in sublist]

# Clean predictions
all_preds_clean = [p for p in all_preds_flat if len(p) == 7]
all_targets_clean = [t for t in all_targets_flat if len(t) == 6]

results, mAP50 = evaluate_detections(all_preds_clean, all_targets_clean, iou_thresh=0.6)

for cls, metrics in results.items():
    print(f"Class {cls}:")
    print(f"  Precision: {metrics['precision']:.4f}")
    print(f"  Recall:    {metrics['recall']:.4f}")
    print(f"  F1 Score:  {metrics['f1']:.4f}")
    print(f"  AP@0.5:    {metrics['ap50']:.4f}")
print(f"  count:     {count}")
print(f"\nMean AP@0.5 (mAP50): {mAP50:.4f}")
# Out:
# Class 0:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
# Class 1:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
# Class 2:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
# Class 3:
#   Precision: 0.0063
#   Recall:    0.0053
#   F1 Score:  0.0057
#   AP@0.5:    0.0000
# Class 4:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
# Class 5:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
# Class 6:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
# Class 7:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
# Class 8:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
#   count:     24
#
# Mean AP@0.5 (mAP50): 0.0000

# %% [markdown]
# # ed

# %%
image_id = 0
count=0
all_preds = []
all_targets = []
for img_path in image_dir.glob('*.jpg'):
    img = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (28,28))
    img = np.array(img, dtype=np.float32) / 255.0
    img = img.flatten()
    if ed(img) < 0.82 :
        img_tensor, img0 = load_image(img_path)  # Should return a tensor [1,3,H,W] and original image
        preds, targets = pedict(img_tensor, img0, img_path, image_id)
        all_preds.append(preds)
        all_targets.append(targets)
        count+=1
    image_id += 1

all_preds_flat = [item for sublist in all_preds for item in sublist]
all_targets_flat = [item for sublist in all_targets for item in sublist]

# Clean predictions
all_preds_clean = [p for p in all_preds_flat if len(p) == 7]
all_targets_clean = [t for t in all_targets_flat if len(t) == 6]

results, mAP50 = evaluate_detections(all_preds_clean, all_targets_clean, iou_thresh=0.6)

for cls, metrics in results.items():
    print(f"Class {cls}:")
    print(f"  Precision: {metrics['precision']:.4f}")
    print(f"  Recall:    {metrics['recall']:.4f}")
    print(f"  F1 Score:  {metrics['f1']:.4f}")
    print(f"  AP@0.5:    {metrics['ap50']:.4f}")
print(f"  count:     {count}")
print(f"\nMean AP@0.5 (mAP50): {mAP50:.4f}")
# Out:
# Class 0:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
# Class 1:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
# Class 2:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
# Class 3:
#   Precision: 0.0063
#   Recall:    0.0053
#   F1 Score:  0.0057
#   AP@0.5:    0.0000
# Class 4:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
# Class 5:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
# Class 6:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
# Class 7:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
# Class 8:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
#   count:     24
#
# Mean AP@0.5 (mAP50): 0.0000

# %%
image_id = 0
count=0
all_preds = []
all_targets = []
for img_path in image_dir.glob('*.jpg'):
    img = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (28,28))
    img = np.array(img, dtype=np.float32) / 255.0
    img = img.flatten()
    if ed(img) >  0.82 :
        img_tensor, img0 = load_image(img_path)  # Should return a tensor [1,3,H,W] and original image
        preds, targets = pedict(img_tensor, img0, img_path, image_id)
        all_preds.append(preds)
        all_targets.append(targets)
        count+=1
    image_id += 1

all_preds_flat = [item for sublist in all_preds for item in sublist]
all_targets_flat = [item for sublist in all_targets for item in sublist]

# Clean predictions
all_preds_clean = [p for p in all_preds_flat if len(p) == 7]
all_targets_clean = [t for t in all_targets_flat if len(t) == 6]

results, mAP50 = evaluate_detections(all_preds_clean, all_targets_clean, iou_thresh=0.6)

for cls, metrics in results.items():
    print(f"Class {cls}:")
    print(f"  Precision: {metrics['precision']:.4f}")
    print(f"  Recall:    {metrics['recall']:.4f}")
    print(f"  F1 Score:  {metrics['f1']:.4f}")
    print(f"  AP@0.5:    {metrics['ap50']:.4f}")
print(f"  count:     {count}")
print(f"\nMean AP@0.5 (mAP50): {mAP50:.4f}")
# Out:
#   count:     0
#
# Mean AP@0.5 (mAP50): 0.0000

# %% [markdown]
# # complexity

# %%
image_id = 0
count=0
all_preds = []
all_targets = []
for img_path in image_dir.glob('*.jpg'):
    img = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (28,28))
    img = np.array(img, dtype=np.float32) / 255.0
    img = img.flatten()
    if complexity(img)<0.69 or complexity(img)>1.85:
        img_tensor, img0 = load_image(img_path)  # Should return a tensor [1,3,H,W] and original image
        preds, targets = pedict(img_tensor, img0, img_path, image_id)
        all_preds.append(preds)
        all_targets.append(targets)
        count+=1
    image_id += 1

all_preds_flat = [item for sublist in all_preds for item in sublist]
all_targets_flat = [item for sublist in all_targets for item in sublist]

# Clean predictions
all_preds_clean = [p for p in all_preds_flat if len(p) == 7]
all_targets_clean = [t for t in all_targets_flat if len(t) == 6]

results, mAP50 = evaluate_detections(all_preds_clean, all_targets_clean, iou_thresh=0.6)

for cls, metrics in results.items():
    print(f"Class {cls}:")
    print(f"  Precision: {metrics['precision']:.4f}")
    print(f"  Recall:    {metrics['recall']:.4f}")
    print(f"  F1 Score:  {metrics['f1']:.4f}")
    print(f"  AP@0.5:    {metrics['ap50']:.4f}")
print(f"  count:     {count}")
print(f"\nMean AP@0.5 (mAP50): {mAP50:.4f}")
# Out:
#   count:     0
#
# Mean AP@0.5 (mAP50): 0.0000

# %%
image_id = 0
count=0
all_preds = []
all_targets = []
for img_path in image_dir.glob('*.jpg'):
    img = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (28,28))
    img = np.array(img, dtype=np.float32) / 255.0
    img = img.flatten()
    if complexity(img)>0.69 and complexity(img)<1.85:
        img_tensor, img0 = load_image(img_path)  # Should return a tensor [1,3,H,W] and original image
        preds, targets = pedict(img_tensor, img0, img_path, image_id)
        all_preds.append(preds)
        all_targets.append(targets)
        count+=1
    image_id += 1

all_preds_flat = [item for sublist in all_preds for item in sublist]
all_targets_flat = [item for sublist in all_targets for item in sublist]

# Clean predictions
all_preds_clean = [p for p in all_preds_flat if len(p) == 7]
all_targets_clean = [t for t in all_targets_flat if len(t) == 6]

results, mAP50 = evaluate_detections(all_preds_clean, all_targets_clean, iou_thresh=0.6)

for cls, metrics in results.items():
    print(f"Class {cls}:")
    print(f"  Precision: {metrics['precision']:.4f}")
    print(f"  Recall:    {metrics['recall']:.4f}")
    print(f"  F1 Score:  {metrics['f1']:.4f}")
    print(f"  AP@0.5:    {metrics['ap50']:.4f}")
print(f"  count:     {count}")
print(f"\nMean AP@0.5 (mAP50): {mAP50:.4f}")
# Out:
# Class 0:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
# Class 1:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
# Class 2:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
# Class 3:
#   Precision: 0.0063
#   Recall:    0.0053
#   F1 Score:  0.0057
#   AP@0.5:    0.0000
# Class 4:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
# Class 5:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
# Class 6:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
# Class 7:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
# Class 8:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
#   count:     24
#
# Mean AP@0.5 (mAP50): 0.0000

# %% [markdown]
# # brightness

# %%
image_id = 0
count=0
all_preds = []
all_targets = []
for img_path in image_dir.glob('*.jpg'):
    img = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (28,28))
    img = np.array(img, dtype=np.float32) / 255.0
    img = img.flatten()
    if brightness(img) < 0.004 or brightness(img)>0.74:
        img_tensor, img0 = load_image(img_path)  # Should return a tensor [1,3,H,W] and original image
        preds, targets = pedict(img_tensor, img0, img_path, image_id)
        all_preds.append(preds)
        all_targets.append(targets)
        count+=1
    image_id += 1

all_preds_flat = [item for sublist in all_preds for item in sublist]
all_targets_flat = [item for sublist in all_targets for item in sublist]

# Clean predictions
all_preds_clean = [p for p in all_preds_flat if len(p) == 7]
all_targets_clean = [t for t in all_targets_flat if len(t) == 6]

results, mAP50 = evaluate_detections(all_preds_clean, all_targets_clean, iou_thresh=0.6)

for cls, metrics in results.items():
    print(f"Class {cls}:")
    print(f"  Precision: {metrics['precision']:.4f}")
    print(f"  Recall:    {metrics['recall']:.4f}")
    print(f"  F1 Score:  {metrics['f1']:.4f}")
    print(f"  AP@0.5:    {metrics['ap50']:.4f}")
print(f"  count:     {count}")
print(f"\nMean AP@0.5 (mAP50): {mAP50:.4f}")
# Out:
#   count:     0
#
# Mean AP@0.5 (mAP50): 0.0000

# %%
image_id = 0
count=0
all_preds = []
all_targets = []
for img_path in image_dir.glob('*.jpg'):
    img = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (28,28))
    img = np.array(img, dtype=np.float32) / 255.0
    img = img.flatten()
    if brightness(img) > 0.004 and brightness(img)<0.74:
        img_tensor, img0 = load_image(img_path)  # Should return a tensor [1,3,H,W] and original image
        preds, targets = pedict(img_tensor, img0, img_path, image_id)
        all_preds.append(preds)
        all_targets.append(targets)
        count+=1
    image_id += 1

all_preds_flat = [item for sublist in all_preds for item in sublist]
all_targets_flat = [item for sublist in all_targets for item in sublist]

# Clean predictions
all_preds_clean = [p for p in all_preds_flat if len(p) == 7]
all_targets_clean = [t for t in all_targets_flat if len(t) == 6]

results, mAP50 = evaluate_detections(all_preds_clean, all_targets_clean, iou_thresh=0.6)

for cls, metrics in results.items():
    print(f"Class {cls}:")
    print(f"  Precision: {metrics['precision']:.4f}")
    print(f"  Recall:    {metrics['recall']:.4f}")
    print(f"  F1 Score:  {metrics['f1']:.4f}")
    print(f"  AP@0.5:    {metrics['ap50']:.4f}")
print(f"  count:     {count}")
print(f"\nMean AP@0.5 (mAP50): {mAP50:.4f}")
# Out:
# Class 0:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
# Class 1:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
# Class 2:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
# Class 3:
#   Precision: 0.0063
#   Recall:    0.0053
#   F1 Score:  0.0057
#   AP@0.5:    0.0000
# Class 4:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
# Class 5:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
# Class 6:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
# Class 7:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
# Class 8:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
#   count:     24
#
# Mean AP@0.5 (mAP50): 0.0000
