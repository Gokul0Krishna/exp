# %% [markdown]
# <a href="https://colab.research.google.com/github/Gokul0Krishna/exp/blob/main/testsite4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # bg code

# %%
# !unzip "/content/First Pedestrian Test.v1i.yolov5pytorch.zip"
# Out:
# Archive:  /content/First Pedestrian Test.v1i.yolov5pytorch.zip
#  extracting: README.dataset.txt
#  extracting: README.roboflow.txt
#  extracting: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/FudanPed00002_png.rf.447967fb2856d3a97a11d8a0826dd6d4.jpg
#  extracting: test/images/FudanPed00003_png.rf.640bf6ed8762f84cd99589bca470196e.jpg
#  extracting: test/images/FudanPed00005_png.rf.ef31fa83cab8f1045d12db7d9ff7aecb.jpg
#  extracting: test/images/FudanPed00026_png.rf.3a00d388743f19cd98760b5bd7cb1032.jpg
#  extracting: test/images/FudanPed00029_png.rf.80ea78afbfe18797806e86a3a7037d4d.jpg
#  extracting: test/images/FudanPed00042_png.rf.0b94c1ccd1aafa6e74225dc928fd6f43.jpg
#  extracting: test/images/PennPed00003_png.rf.d119c059cb75b0633c52c5d753a4207e.jpg
#  extracting: test/images/PennPed00007_png.rf.cf92a8fb5c7f7635ecc1c8995b9b5522.jpg
#  extracting: test/images/PennPed00011_png.rf.96457f1ae5745d38aad02a3e16d17b7a.jpg
#  extracting: test/images/PennPed00013_png.rf.4cd560e6c2a2c7ae56e6714bb0993dbf.jpg
#  extracting: test/images/PennPed00014_png.rf.211a29ca92eb1b1aa8e5dbc42faf44ad.jpg
#  extracting: test/images/PennPed00017_png.rf.ea72a7dad87dce517007812780191b97.jpg
#  extracting: test/images/PennPed00019_png.rf.aff7b62ea37fb6fc5903a7465cb2a89d.jpg
#  extracting: test/images/PennPed00029_png.rf.5867fda1bd269bf1d2be0b50e1ffe823.jpg
#  extracting: test/images/PennPed00045_png.rf.aae01e1aec6e489fe96c6b5175dfe92e.jpg
#  extracting: test/images/PennPed00052_png.rf.ddcc59210b6f701752a7ed2d10ed0b65.jpg
#  extracting: test/images/PennPed00061_png.rf.9d08809def9cab82897698212978926d.jpg
#  extracting: test/images/PennPed00065_png.rf.86b25c187a4f338ad9f0dab4337fa564.jpg
#  extracting: test/images/PennPed00066_png.rf.a6f8bd9b2abf5aa2890aff0536773130.jpg
#  extracting: test/images/PennPed00074_png.rf.abd308976200bfd07a65d602bc9211c7.jpg
#  extracting: test/images/PennPed00083_png.rf.485d6eb2e89deb596356fd137cdffd71.jpg
#  extracting: test/images/PennPed00092_png.rf.6814dee4fbe6a5b58ab751b7be2fccde.jpg
#  extracting: test/images/PennPed00093_png.rf.29a4c4febdf9bd98b7b8db87bddb8ede.jpg
#    creating: test/labels/
#  extracting: test/labels/FudanPed00002_png.rf.447967fb2856d3a97a11d8a0826dd6d4.txt
#  extracting: test/labels/FudanPed00003_png.rf.640bf6ed8762f84cd99589bca470196e.txt
#  extracting: test/labels/FudanPed00005_png.rf.ef31fa83cab8f1045d12db7d9ff7aecb.txt
#  extracting: test/labels/FudanPed00026_png.rf.3a00d388743f19cd98760b5bd7cb1032.txt
#  extracting: test/labels/FudanPed00029_png.rf.80ea78afbfe18797806e86a3a7037d4d.txt
#  extracting: test/labels/FudanPed00042_png.rf.0b94c1ccd1aafa6e74225dc928fd6f43.txt
#  extracting: test/labels/PennPed00003_png.rf.d119c059cb75b0633c52c5d753a4207e.txt
#  extracting: test/labels/PennPed00007_png.rf.cf92a8fb5c7f7635ecc1c8995b9b5522.txt
#  extracting: test/labels/PennPed00011_png.rf.96457f1ae5745d38aad02a3e16d17b7a.txt
#  extracting: test/labels/PennPed00013_png.rf.4cd560e6c2a2c7ae56e6714bb0993dbf.txt
#  extracting: test/labels/PennPed00014_png.rf.211a29ca92eb1b1aa8e5dbc42faf44ad.txt
#  extracting: test/labels/PennPed00017_png.rf.ea72a7dad87dce517007812780191b97.txt
#  extracting: test/labels/PennPed00019_png.rf.aff7b62ea37fb6fc5903a7465cb2a89d.txt
#  extracting: test/labels/PennPed00029_png.rf.5867fda1bd269bf1d2be0b50e1ffe823.txt
#  extracting: test/labels/PennPed00045_png.rf.aae01e1aec6e489fe96c6b5175dfe92e.txt
#  extracting: test/labels/PennPed00052_png.rf.ddcc59210b6f701752a7ed2d10ed0b65.txt
#  extracting: test/labels/PennPed00061_png.rf.9d08809def9cab82897698212978926d.txt
#  extracting: test/labels/PennPed00065_png.rf.86b25c187a4f338ad9f0dab4337fa564.txt
#  extracting: test/labels/PennPed00066_png.rf.a6f8bd9b2abf5aa2890aff0536773130.txt
#  extracting: test/labels/PennPed00074_png.rf.abd308976200bfd07a65d602bc9211c7.txt
#  extracting: test/labels/PennPed00083_png.rf.485d6eb2e89deb596356fd137cdffd71.txt
#  extracting: test/labels/PennPed00092_png.rf.6814dee4fbe6a5b58ab751b7be2fccde.txt
#  extracting: test/labels/PennPed00093_png.rf.29a4c4febdf9bd98b7b8db87bddb8ede.txt
#    creating: train/
#    creating: train/images/
#  extracting: train/images/FudanPed00001_png.rf.0b11b2eb66b57ef60f7f906ca2e481aa.jpg
#  extracting: train/images/FudanPed00001_png.rf.10e9884f4e7f83352c085397258b0d7f.jpg
#  extracting: train/images/FudanPed00001_png.rf.5cc7ef7cd152486910e8f8c0d69738f7.jpg
#  extracting: train/images/FudanPed00004_png.rf.78800ccc4be3ce4cb4e61e6b3d87eb96.jpg
#  extracting: train/images/FudanPed00004_png.rf.796c028e4e9f5c1f5fa2920700871ef6.jpg
#  extracting: train/images/FudanPed00004_png.rf.ef4b98c0570a674720290395b00fb1be.jpg
#  extracting: train/images/FudanPed00007_png.rf.280cfc2a1aed351b81899a6c1c5f243b.jpg
#  extracting: train/images/FudanPed00007_png.rf.753bd5996ea571504eb06b3c6191a9ba.jpg
#  extracting: train/images/FudanPed00007_png.rf.d886a78277a7fb41bdf3e4292ed64cd1.jpg
#  extracting: train/images/FudanPed00008_png.rf.637bbf23811ce3ba2a04ff88f565405e.jpg
#  extracting: train/images/FudanPed00008_png.rf.b882fcb88d3cd22d45aa960308819d40.jpg
#  extracting: train/images/FudanPed00008_png.rf.f5e8c284b153dbb9e7164c889c1f3474.jpg
#  extracting: train/images/FudanPed00009_png.rf.22d360630aedca375737ff22f4e91fe1.jpg
#  extracting: train/images/FudanPed00009_png.rf.38c85f85067fd52f6e691ce900ac4257.jpg
#  extracting: train/images/FudanPed00009_png.rf.5603d733276a0fe801468dee74bbb43f.jpg
#  extracting: train/images/FudanPed00011_png.rf.200a309f17072acb0199da7d52378438.jpg
#  extracting: train/images/FudanPed00011_png.rf.91dba1da76d673853706df99d44fbbfd.jpg
#  extracting: train/images/FudanPed00011_png.rf.d60e21a576a22764f13efd8b13bc5a8f.jpg
#  extracting: train/images/FudanPed00012_png.rf.006daf90bf226801db2080dd29eca4b4.jpg
#  extracting: train/images/FudanPed00012_png.rf.1e62009154e66f2392f67ea06d33af21.jpg
#  extracting: train/images/FudanPed00012_png.rf.ec7360d1c48dcba6cdd8130bb08ae053.jpg
#  extracting: train/images/FudanPed00013_png.rf.3374974743d20582c1abe3dbbab9eebc.jpg
#  extracting: train/images/FudanPed00013_png.rf.381cf3ec71c843204be4e18f2e69c4e1.jpg
#  extracting: train/images/FudanPed00013_png.rf.85f20ff6e4ecf962f3b5c2b96d6ae041.jpg
#  extracting: train/images/FudanPed00014_png.rf.17868129c8e5c2a4933a710726400ee4.jpg
#  extracting: train/images/FudanPed00014_png.rf.79fce8f3d7cbdcfe9d09c82ce7314cfc.jpg
#  extracting: train/images/FudanPed00014_png.rf.992253e01472b9d00ff2bd17240c3277.jpg
#  extracting: train/images/FudanPed00015_png.rf.1cf283d2b93254d6f44ab5dea5cc5ef1.jpg
#  extracting: train/images/FudanPed00015_png.rf.878b681ca89ab37ba5b72dc06c47842d.jpg
#  extracting: train/images/FudanPed00015_png.rf.d297cd14a350a9e4ab27e8cbebf37177.jpg
#  extracting: train/images/FudanPed00016_png.rf.3878288d25f1d881a94c67945f1359b5.jpg
#  extracting: train/images/FudanPed00016_png.rf.50e52fc3bbcf082b756574903e4f232b.jpg
#  extracting: train/images/FudanPed00016_png.rf.a67e8a86a31892c081261828e1f0c59f.jpg
#  extracting: train/images/FudanPed00017_png.rf.148c42bac6d021b9e55e37c187a168e8.jpg
#  extracting: train/images/FudanPed00017_png.rf.daf2624f3dc637b7386341b385b780c5.jpg
#  extracting: train/images/FudanPed00017_png.rf.f9c35067310be22d6cd864cdd9c857bd.jpg
#  extracting: train/images/FudanPed00019_png.rf.9d7d03f08082a588042107632bcf6122.jpg
#  extracting: train/images/FudanPed00019_png.rf.c875981439ab0a98c501ce6c9615c07a.jpg
#  extracting: train/images/FudanPed00019_png.rf.e9aff36d905dc8996b22b90853c7ecdb.jpg
#  extracting: train/images/FudanPed00022_png.rf.2b4bf43b82cf36d5937e7ef85de1d99e.jpg
#  extracting: train/images/FudanPed00022_png.rf.5fcadf12169573bd795163bb74506610.jpg
#  extracting: train/images/FudanPed00022_png.rf.5ff5434f7e3ec9839eb605a5e2bfcda6.jpg
#  extracting: train/images/FudanPed00023_png.rf.5195ce7245e7c4e3e298f8c2d8542585.jpg
#  extracting: train/images/FudanPed00023_png.rf.dfc9dac7f4bda538cc4cf40aff9ec0c9.jpg
#  extracting: train/images/FudanPed00023_png.rf.ff580e66654ec9a25f60787c34a8d393.jpg
#  extracting: train/images/FudanPed00024_png.rf.14d70d97fbd18cf6615c96eb5f4358b8.jpg
#  extracting: train/images/FudanPed00024_png.rf.3ad535b496b3adac7ce2f51f009163fd.jpg
#  extracting: train/images/FudanPed00024_png.rf.9ed2e32aa60192c7b4403b39020bcfb9.jpg
#  extracting: train/images/FudanPed00027_png.rf.4cfe371acca20c5e98ddc55da460f362.jpg
#  extracting: train/images/FudanPed00027_png.rf.6581326ebb90f635be8e1a7ef8b8c503.jpg
#  extracting: train/images/FudanPed00027_png.rf.88fe0a887675f423e4aa20ab78521a66.jpg
#  extracting: train/images/FudanPed00032_png.rf.838565d53d67ce43956c3392fb338576.jpg
#  extracting: train/images/FudanPed00032_png.rf.d746194d201e2725b53cad965b6f472d.jpg
#  extracting: train/images/FudanPed00032_png.rf.dce79f89c609f7cc1a7a1eefbad6cfa7.jpg
#  extracting: train/images/FudanPed00033_png.rf.2f69f8dad9bc6f7afeab94ea05291698.jpg
#  extracting: train/images/FudanPed00033_png.rf.5c3b834cdf59a19b03e6684f3e14bb57.jpg
#  extracting: train/images/FudanPed00033_png.rf.5e750f7c7c231a90b6beb5687e8ee877.jpg
#  extracting: train/images/FudanPed00035_png.rf.2371e45a74296c2fb8233e3234c7a874.jpg
#  extracting: train/images/FudanPed00035_png.rf.5488089fba59c4d5db4cd3e882008981.jpg
#  extracting: train/images/FudanPed00035_png.rf.d7bdc041b1b5b28d3c3e71a827e5bd86.jpg
#  extracting: train/images/FudanPed00036_png.rf.1bba6015dfeba4ca34ae11e1e2ce6dcc.jpg
#  extracting: train/images/FudanPed00036_png.rf.7a147910c20db8b7ee4184881652e2a5.jpg
#  extracting: train/images/FudanPed00036_png.rf.f23e7b4316af19066f8553991be14431.jpg
#  extracting: train/images/FudanPed00037_png.rf.627fbc9be70fd6839720ed05b9e43fd7.jpg
#  extracting: train/images/FudanPed00037_png.rf.b2d83447611576b22dbe2f3dbe688eb8.jpg
#  extracting: train/images/FudanPed00037_png.rf.e10ce76823da95a17c7ef83bbca32f77.jpg
#  extracting: train/images/FudanPed00038_png.rf.08bc230b814f856c7bec407b87c15e85.jpg
#  extracting: train/images/FudanPed00038_png.rf.5fe763852ae968e1b3790db0cedc3810.jpg
#  extracting: train/images/FudanPed00038_png.rf.890c8b7f640b89ef122d56294cae2795.jpg
#  extracting: train/images/FudanPed00039_png.rf.445dbe3394a1b20e24b6f1e4924f9766.jpg
#  extracting: train/images/FudanPed00039_png.rf.4972662d410156a0f5b497938f75ef0d.jpg
#  extracting: train/images/FudanPed00039_png.rf.7216b9e69343b9318841e678d2d945b2.jpg
#  extracting: train/images/FudanPed00040_png.rf.693df3b39d030da36862e5f713fd2cc5.jpg
#  extracting: train/images/FudanPed00040_png.rf.6d95619796a050db33cb892b845dd33f.jpg
#  extracting: train/images/FudanPed00040_png.rf.8331eb143f19406a538b5785f33ec198.jpg
#  extracting: train/images/FudanPed00041_png.rf.376a816c74f2e4adda69921a28d741e8.jpg
#  extracting: train/images/FudanPed00041_png.rf.9f82a8d0642ed4189a34f80db6516e5a.jpg
#  extracting: train/images/FudanPed00041_png.rf.d8604cfd0dc5f9bee979418fd2d681db.jpg
#  extracting: train/images/FudanPed00043_png.rf.2352510f1810d8aaf75d7dd55bda626a.jpg
#  extracting: train/images/FudanPed00043_png.rf.5f3ebecc45b805f3953e83552bbb4599.jpg
#  extracting: train/images/FudanPed00043_png.rf.cffcacc00ab5abb1d68e565d47083684.jpg
#  extracting: train/images/FudanPed00044_png.rf.3559ea1418590460b52c8b919d7ba38f.jpg
#  extracting: train/images/FudanPed00044_png.rf.95778e750b7fdb562e4bc30be10d06e7.jpg
#  extracting: train/images/FudanPed00044_png.rf.e17ce025387ebed42eef165781ba8caa.jpg
#  extracting: train/images/FudanPed00045_png.rf.57256537000ea7bd96acde1c4bd6d71c.jpg
#  extracting: train/images/FudanPed00045_png.rf.e3e9f658990517618fb70aee91f198fc.jpg
#  extracting: train/images/FudanPed00045_png.rf.e4844b67b27ae792c6521ab93ef698e4.jpg
#  extracting: train/images/FudanPed00046_png.rf.705365e4ea82c8fa27b801050e7f2a9c.jpg
#  extracting: train/images/FudanPed00046_png.rf.b0ef058ebea91720ee5fba32eb91ab17.jpg
#  extracting: train/images/FudanPed00046_png.rf.c912acd4aef91e3025c5ea28e093fe89.jpg
#  extracting: train/images/FudanPed00047_png.rf.581d9cfbb0e9fb62fb858dad4727b07a.jpg
#  extracting: train/images/FudanPed00047_png.rf.6f606144796fd981f03c4f2a3420b295.jpg
#  extracting: train/images/FudanPed00047_png.rf.9578e9cc09ac1d4e1c1704c2289d3df9.jpg
#  extracting: train/images/FudanPed00050_png.rf.9de726e33a52c36838b832d51ed5e412.jpg
#  extracting: train/images/FudanPed00050_png.rf.a77fa5c9182b1d2e91d8e846d8baad76.jpg
#  extracting: train/images/FudanPed00050_png.rf.d5b1ae4d78d40739d229f326c3fc07e8.jpg
#  extracting: train/images/FudanPed00051_png.rf.14fd53cdda54e6c48c61b019485bf0f5.jpg
#  extracting: train/images/FudanPed00051_png.rf.24456458b2e5e912436582e84bbd37b2.jpg
#  extracting: train/images/FudanPed00051_png.rf.2e5cabddcf3387f4e93e493e268c683c.jpg
#  extracting: train/images/FudanPed00053_png.rf.01517c76163641d21b149e357491f09f.jpg
#  extracting: train/images/FudanPed00053_png.rf.7844d906e5d8474456e31148e8306690.jpg
#  extracting: train/images/FudanPed00053_png.rf.cdd8fca4f7cab22cd528116c7b8ce536.jpg
#  extracting: train/images/FudanPed00054_png.rf.1f0242bd648e28210c1449d96ad66708.jpg
#  extracting: train/images/FudanPed00054_png.rf.29f8f6263350804a8337fbb3d075418b.jpg
#  extracting: train/images/FudanPed00054_png.rf.c0ad7a842e4b7afb925ca6d72cffab03.jpg
#  extracting: train/images/FudanPed00057_png.rf.25ceaa4246859e6dc2b2f5ef15a3cc8e.jpg
#  extracting: train/images/FudanPed00057_png.rf.8948f7637d8339c1a93172ee65f9c12d.jpg
#  extracting: train/images/FudanPed00057_png.rf.ea9fadd57a2becc46b4a95953eeff9b2.jpg
#  extracting: train/images/FudanPed00058_png.rf.1d2ce9ac169ec3a30bc8efee98dfaf96.jpg
#  extracting: train/images/FudanPed00058_png.rf.b0c93ace3109513b273b8432f2b1fd64.jpg
#  extracting: train/images/FudanPed00058_png.rf.db17d130f2f5ba557359a6f588f01db9.jpg
#  extracting: train/images/FudanPed00059_png.rf.78fe2bf6195b8699f44bc0907bd58ced.jpg
#  extracting: train/images/FudanPed00059_png.rf.82bc3821ef306c8dc7147a7e430fd34e.jpg
#  extracting: train/images/FudanPed00059_png.rf.aaced9987e27aea3e87d81f36d4736b6.jpg
#  extracting: train/images/FudanPed00060_png.rf.0f93fd8908894796bf76dc4cd64d0394.jpg
#  extracting: train/images/FudanPed00060_png.rf.15b0d99eccf98230bcf4aff846149002.jpg
#  extracting: train/images/FudanPed00060_png.rf.1c079d292b4baefe3a126c59b871cfd9.jpg
#  extracting: train/images/FudanPed00061_png.rf.80d0602940e696a9b5cc858467ebea3d.jpg
#  extracting: train/images/FudanPed00061_png.rf.af2298bab7bb78c6ed8a5786dfe88839.jpg
#  extracting: train/images/FudanPed00061_png.rf.f37ea231fe8a1c67aeeb9528ff3eeb77.jpg
#  extracting: train/images/FudanPed00062_png.rf.0b5e8423f667541b3d9c96fd361c68d0.jpg
#  extracting: train/images/FudanPed00062_png.rf.60f7dc35e797e4714a69166e687f9250.jpg
#  extracting: train/images/FudanPed00062_png.rf.ef87c70d28af147e6d561b8c3a2c3e6d.jpg
#  extracting: train/images/FudanPed00063_png.rf.11a5a7e4e6d8574f0f843e7d3dcbeb0e.jpg
#  extracting: train/images/FudanPed00063_png.rf.3456c1c66197e65551aa64c08047ffe5.jpg
#  extracting: train/images/FudanPed00063_png.rf.b33b2312b15abe35231f67cca3216cb5.jpg
#  extracting: train/images/FudanPed00064_png.rf.45243750bc65c15cb88022494947f5e8.jpg
#  extracting: train/images/FudanPed00064_png.rf.f1cb52aecc9d76fa87e3ba6aed9eed58.jpg
#  extracting: train/images/FudanPed00064_png.rf.f46c55700fb85c49a38608cbdebc05a2.jpg
#  extracting: train/images/FudanPed00065_png.rf.1f008eccbd296045335499a997654b36.jpg
#  extracting: train/images/FudanPed00065_png.rf.5cf24f6b2ba11cdb69580c0386d9f0c7.jpg
#  extracting: train/images/FudanPed00065_png.rf.6a96425cd3eeb9539525d2fd659573a4.jpg
#  extracting: train/images/FudanPed00066_png.rf.3b88e1fc44e64a31ed20ba79ded491ab.jpg
#  extracting: train/images/FudanPed00066_png.rf.9f006b403942909a2b6f7defa0a22f81.jpg
#  extracting: train/images/FudanPed00066_png.rf.e8a020b61f72fd5fb5e286780d65ef96.jpg
#  extracting: train/images/FudanPed00067_png.rf.b8159c89e80d22f334ec13b0645193c6.jpg
#  extracting: train/images/FudanPed00067_png.rf.bab43494b8d40ac5f11df6ea48266c44.jpg
#  extracting: train/images/FudanPed00067_png.rf.d847ce65a548eef7c4178d49de22f1ed.jpg
#  extracting: train/images/FudanPed00071_png.rf.221b5cee29c0cf8332f3d8315d7d25e6.jpg
#  extracting: train/images/FudanPed00071_png.rf.2954bc5febcbbc2c0b797f05c520dd55.jpg
#  extracting: train/images/FudanPed00071_png.rf.a13f746a59bc52819e7065fbc7c767f4.jpg
#  extracting: train/images/FudanPed00072_png.rf.574a7b0a16888e6ce75aa608efe6bdae.jpg
#  extracting: train/images/FudanPed00072_png.rf.967d22f24821a0f5cdd593495c2717be.jpg
#  extracting: train/images/FudanPed00072_png.rf.eeb40cd709021fab02909c427f6464c3.jpg
#  extracting: train/images/PennPed00002_png.rf.1688f183a532afd5c6e3b14b48a3d254.jpg
#  extracting: train/images/PennPed00002_png.rf.b5bd1877f7c084da6da129aa7f5e9ed7.jpg
#  extracting: train/images/PennPed00002_png.rf.fada2bb2ae4d926c1a90c18ed197168a.jpg
#  extracting: train/images/PennPed00004_png.rf.04103bf629c9c3d9da2228d6743cbf9e.jpg
#  extracting: train/images/PennPed00004_png.rf.68cdb900a18cca315d1f081bc29cdb79.jpg
#  extracting: train/images/PennPed00004_png.rf.9f1de4136d4b87bda762adf045ddca5d.jpg
#  extracting: train/images/PennPed00005_png.rf.448108388d7cd5ab6ec05e67719a7394.jpg
#  extracting: train/images/PennPed00005_png.rf.4e791ef621ee5aaddd05510e5a02b77f.jpg
#  extracting: train/images/PennPed00005_png.rf.ac5870f08c8456a906472e86b84bf8e0.jpg
#  extracting: train/images/PennPed00006_png.rf.94e405da0ae78daa3dc2918b02620f9b.jpg
#  extracting: train/images/PennPed00006_png.rf.9eff29d999a7bd12f438714113987f87.jpg
#  extracting: train/images/PennPed00006_png.rf.af23fe38720f20cd256f31cd83a0c953.jpg
#  extracting: train/images/PennPed00008_png.rf.2adea0baaadbfbe664d860280ef633aa.jpg
#  extracting: train/images/PennPed00008_png.rf.d4cd353726b604466e2be26ec6347fac.jpg
#  extracting: train/images/PennPed00008_png.rf.f561cbbce7eccd86888211fd95231490.jpg
#  extracting: train/images/PennPed00009_png.rf.93035775fa6dfa677e1f1490787d3b96.jpg
#  extracting: train/images/PennPed00009_png.rf.9af5fb29142849208f50eb5f7dc45689.jpg
#  extracting: train/images/PennPed00009_png.rf.f05090d464a35f704df65be406f1af8c.jpg
#  extracting: train/images/PennPed00010_png.rf.73d33c0de33fdf4380001666d4f0c987.jpg
#  extracting: train/images/PennPed00010_png.rf.97d32abeda2ec42644d538ca8e800929.jpg
#  extracting: train/images/PennPed00010_png.rf.cd9a1d8c0d7c6b271494ebd484ae3c56.jpg
#  extracting: train/images/PennPed00012_png.rf.74717c71efd00cb715aada6db483a77c.jpg
#  extracting: train/images/PennPed00012_png.rf.8ef64f926c2dfe378f96f12932612d31.jpg
#  extracting: train/images/PennPed00012_png.rf.9e253d971b9bedb4001c68a02f34fb14.jpg
#  extracting: train/images/PennPed00015_png.rf.3f737dbf645ec54a949a6de85c170111.jpg
#  extracting: train/images/PennPed00015_png.rf.40f866e816a947f816e012ba7d183be0.jpg
#  extracting: train/images/PennPed00015_png.rf.905924692d9a589fb551c7e3fd127e93.jpg
#  extracting: train/images/PennPed00016_png.rf.41cc7c156581cddb94dad63911eb0f1f.jpg
#  extracting: train/images/PennPed00016_png.rf.8ca2d57aeb19bbde8b9d2978fa4a955f.jpg
#  extracting: train/images/PennPed00016_png.rf.9bb7c6c2d9de73e0d1337f7dbcbf7fcf.jpg
#  extracting: train/images/PennPed00018_png.rf.48910fb608fa6bde56995e89f86fbe85.jpg
#  extracting: train/images/PennPed00018_png.rf.6be604a54d6673ce1b707b2c062e6901.jpg
#  extracting: train/images/PennPed00018_png.rf.f1ae9960cfebdaf26373d285e8d02532.jpg
#  extracting: train/images/PennPed00019_png.rf.2a3f0c57a5681c77736fdf6f74b8dd49.jpg
#  extracting: train/images/PennPed00019_png.rf.6fbe9df9d396c4439eff8f602cfd53d2.jpg
#  extracting: train/images/PennPed00019_png.rf.acc622532c5a556534ac39ab1d265e4c.jpg
#  extracting: train/images/PennPed00020_png.rf.79b7c86709b6c56ed7fe53a51f8cfcdf.jpg
#  extracting: train/images/PennPed00020_png.rf.cfc7555b832f3316fbe40c3711f8f3c2.jpg
#  extracting: train/images/PennPed00020_png.rf.d3f3b31f98808fb03d6a53b4170d0a81.jpg
#  extracting: train/images/PennPed00021_png.rf.d1fbdb60ff904e2028983c626d029713.jpg
#  extracting: train/images/PennPed00021_png.rf.ed96f47cf96072bccd750d76cdf3446f.jpg
#  extracting: train/images/PennPed00021_png.rf.f4fa1534fdf7f27400a630b873120f03.jpg
#  extracting: train/images/PennPed00022_png.rf.27e8561d8bbb9d26c7657217dd1fe07b.jpg
#  extracting: train/images/PennPed00022_png.rf.a6915f5c6deff1c92b5a45c8e4cfc032.jpg
#  extracting: train/images/PennPed00022_png.rf.f8b7949d9a961c9bd3ee28d2042819a6.jpg
#  extracting: train/images/PennPed00023_png.rf.03ce25c8a0ee52b1de4ffe17c60fa8b7.jpg
#  extracting: train/images/PennPed00023_png.rf.e0526b4b6cd1efcef2e49912a141198d.jpg
#  extracting: train/images/PennPed00023_png.rf.f6121f91db533ef35eb0fb92a4237f38.jpg
#  extracting: train/images/PennPed00024_png.rf.4e288916f597422094d464d92c69c80a.jpg
#  extracting: train/images/PennPed00024_png.rf.85aaac5df43220573356425d6bea6a79.jpg
#  extracting: train/images/PennPed00024_png.rf.89b75c43bcaa8467e1a233822b20e787.jpg
#  extracting: train/images/PennPed00024_png.rf.a0b24771429417dcef727f6a32171c37.jpg
#  extracting: train/images/PennPed00024_png.rf.f6918ae8dde5920f03b7a86274eb3995.jpg
#  extracting: train/images/PennPed00024_png.rf.f7669dddc4b6e4def9936273d2d0f786.jpg
#  extracting: train/images/PennPed00025_png.rf.0c5f1e46a40c7017d75a5acdb971c75d.jpg
#  extracting: train/images/PennPed00025_png.rf.63ae3f33932cc948253e716183f91918.jpg
#  extracting: train/images/PennPed00025_png.rf.a0a87d3ff4930c9166c450c5b304591c.jpg
#  extracting: train/images/PennPed00025_png.rf.a66fefcb7403ee7e743eb33c5ad03319.jpg
#  extracting: train/images/PennPed00025_png.rf.b8480f2808c36d6395833be7f7f267cd.jpg
#  extracting: train/images/PennPed00025_png.rf.cac3c80eda0ff19ad01178ddd19eb446.jpg
#  extracting: train/images/PennPed00027_png.rf.1b158eb6c4ac6e31a49ddaa3b385b836.jpg
#  extracting: train/images/PennPed00027_png.rf.58f6d8718c8716ac0df4e13a0aa8d7c1.jpg
#  extracting: train/images/PennPed00027_png.rf.81dc499129a90e0e56ebeceee2e1ea4a.jpg
#  extracting: train/images/PennPed00027_png.rf.8680f22468523effaa9072d440e47f1a.jpg
#  extracting: train/images/PennPed00027_png.rf.9535d37e6133ba0b1cc3482d0031ab9b.jpg
#  extracting: train/images/PennPed00027_png.rf.f50e3e2e83bc6c83ce8c38eee37d0d81.jpg
#  extracting: train/images/PennPed00028_png.rf.2972906e3b0e4b7f75fdfd6471af4596.jpg
#  extracting: train/images/PennPed00028_png.rf.5f70787353e39308a7be3649c09cf57f.jpg
#  extracting: train/images/PennPed00028_png.rf.6f3b043b9f9d86926cd3796d8c2bba6c.jpg
#  extracting: train/images/PennPed00029_png.rf.32531305445a5173e3c2e0770043e411.jpg
#  extracting: train/images/PennPed00029_png.rf.7602f8021876208e22714fb5ffefdb0e.jpg
#  extracting: train/images/PennPed00029_png.rf.7b572caa9593cab3539f358b0d690bba.jpg
#  extracting: train/images/PennPed00030_png.rf.6dc2813a901e7ebf961f468f2532eeb3.jpg
#  extracting: train/images/PennPed00030_png.rf.813bce2e3fe5b4d65c279946a66e1ada.jpg
#  extracting: train/images/PennPed00030_png.rf.f71fd1a386a1e934eb6e313ed5149323.jpg
#  extracting: train/images/PennPed00031_png.rf.2392c69d35540482797be91c1e9b6a1d.jpg
#  extracting: train/images/PennPed00031_png.rf.676d4eb3834b6582b66eb5fca07bbf9c.jpg
#  extracting: train/images/PennPed00031_png.rf.f058c45ead56a42e067466762c735f0b.jpg
#  extracting: train/images/PennPed00032_png.rf.329a87c55fce1f132a92990a65c75366.jpg
#  extracting: train/images/PennPed00032_png.rf.4397cc08eff9828a08f748ce2d0bbac4.jpg
#  extracting: train/images/PennPed00032_png.rf.f81d83edfaf4303faf4ea27ee7c4b338.jpg
#  extracting: train/images/PennPed00033_png.rf.728ea321f136b3c84438c5f6c82b5631.jpg
#  extracting: train/images/PennPed00033_png.rf.87d86c4d3a078a82dabd63910fd1d945.jpg
#  extracting: train/images/PennPed00033_png.rf.b9fb7d6edb633c561d3d5bc950f1ea4c.jpg
#  extracting: train/images/PennPed00034_png.rf.3bf3ea47f615e8dbd2b2c991599d7762.jpg
#  extracting: train/images/PennPed00034_png.rf.4669c267fcc5caebb67cb4bcc5db1d30.jpg
#  extracting: train/images/PennPed00034_png.rf.f17685b9f48099ea201f90b7b34acc12.jpg
#  extracting: train/images/PennPed00035_png.rf.2b782fcb14120406ad8ea05ff11572f8.jpg
#  extracting: train/images/PennPed00035_png.rf.37c902a43a9dfe6266d9ac1db83962a8.jpg
#  extracting: train/images/PennPed00035_png.rf.b0b6139e3be5124386e4612c7df3657b.jpg
#  extracting: train/images/PennPed00036_png.rf.1e0f99b80f942f141737bf9a9c6ddf39.jpg
#  extracting: train/images/PennPed00036_png.rf.9cb1b125fe0b509551acd4d26ee92036.jpg
#  extracting: train/images/PennPed00036_png.rf.d91951a29f97dc83f3aff5583362d88f.jpg
#  extracting: train/images/PennPed00037_png.rf.0a411d35e3e430fc97b291739812ce49.jpg
#  extracting: train/images/PennPed00037_png.rf.8fcd80f1a31ced14b17e45dc1a9ee780.jpg
#  extracting: train/images/PennPed00037_png.rf.a9a529bca6d873898cf4b6a996901205.jpg
#  extracting: train/images/PennPed00037_png.rf.c2c44e593905253366ebe53a9f2147d9.jpg
#  extracting: train/images/PennPed00037_png.rf.e0b51b5bebdd4809014fe4fbdd9065ba.jpg
#  extracting: train/images/PennPed00037_png.rf.f852fb64e898c15173fc2bd90466b484.jpg
#  extracting: train/images/PennPed00038_png.rf.2dd52e20451ca309f2fa278082277038.jpg
#  extracting: train/images/PennPed00038_png.rf.2e36f17f63a621ee17bb0a271696bb25.jpg
#  extracting: train/images/PennPed00038_png.rf.3c708cddd1fc5556f589bd7d3b8593f3.jpg
#  extracting: train/images/PennPed00038_png.rf.798eb568ad9ea2f1097d7bfbe067f354.jpg
#  extracting: train/images/PennPed00038_png.rf.d250e41d22e00a9074cd9439cab1833a.jpg
#  extracting: train/images/PennPed00038_png.rf.ee09d6a12c7d27d70c1bde2c5efc19a7.jpg
#  extracting: train/images/PennPed00042_png.rf.20226f47d7413df1bbb48514bf32ac3a.jpg
#  extracting: train/images/PennPed00042_png.rf.918e1620f5727abd0a475add43ab94f8.jpg
#  extracting: train/images/PennPed00042_png.rf.95ca215aed9350f0adea347b4622032f.jpg
#  extracting: train/images/PennPed00043_png.rf.13f4c7ce6af9b3f152a08a552e4e1a38.jpg
#  extracting: train/images/PennPed00043_png.rf.1cf9bc06cebc7a72b4ea77677a1a9bfa.jpg
#  extracting: train/images/PennPed00043_png.rf.6263af42b26ae22c11fd6bd5cd688a5e.jpg
#  extracting: train/images/PennPed00044_png.rf.2e617fb70d8ed81ea1ee419dd1a66c3b.jpg
#  extracting: train/images/PennPed00044_png.rf.bd586443a59d60f0442dff0e13ef95bf.jpg
#  extracting: train/images/PennPed00044_png.rf.ef9785842576d431a46f9b9aa17861bf.jpg
#  extracting: train/images/PennPed00046_png.rf.395a4851c1114cb63fe6f14125d1745e.jpg
#  extracting: train/images/PennPed00046_png.rf.631ba3540d6f0be8634ffdeb484fdf26.jpg
#  extracting: train/images/PennPed00046_png.rf.e43881dc18c51a2e7e5669f92a0ee8ae.jpg
#  extracting: train/images/PennPed00048_png.rf.4fdfa7ee73da9a90c5bc9d266041505d.jpg
#  extracting: train/images/PennPed00048_png.rf.9800572381da51051de844b4a67ed255.jpg
#  extracting: train/images/PennPed00048_png.rf.f5202ef3201ba998cc329945b03b7b97.jpg
#  extracting: train/images/PennPed00049_png.rf.2d86ea832122386c8f7d63e684501026.jpg
#  extracting: train/images/PennPed00049_png.rf.9589655252b71564953156fa0d52990f.jpg
#  extracting: train/images/PennPed00049_png.rf.e18ba4424619638fd776fd1751b75662.jpg
#  extracting: train/images/PennPed00050_png.rf.0e21031db9f5b1afe81b469cd59310e7.jpg
#  extracting: train/images/PennPed00050_png.rf.a932f2317e9561b9f1082ea7a615e7b5.jpg
#  extracting: train/images/PennPed00050_png.rf.eb8573c6300f266ef1472f79ba35ebd1.jpg
#  extracting: train/images/PennPed00054_png.rf.047ee4d714e89e233577046aaa225ad1.jpg
#  extracting: train/images/PennPed00054_png.rf.27eb8ae9b93e5b1089ba8a9808d0813a.jpg
#  extracting: train/images/PennPed00054_png.rf.716cb08db2421bcfccf41bdb7e29dc67.jpg
#  extracting: train/images/PennPed00054_png.rf.a6e196fa9e46ac5ad87a29b2db3900ec.jpg
#  extracting: train/images/PennPed00054_png.rf.be3b5f72284c6fdf4229169582884317.jpg
#  extracting: train/images/PennPed00054_png.rf.f6731bad16eaa67967a9660ca95ecbbf.jpg
#  extracting: train/images/PennPed00056_png.rf.25dc862c013a0a341302e750297d5eeb.jpg
#  extracting: train/images/PennPed00056_png.rf.48ee500feeebb4a15a0a1c4f8cd51629.jpg
#  extracting: train/images/PennPed00056_png.rf.c559f4df5320f79f1185692b182150ac.jpg
#  extracting: train/images/PennPed00057_png.rf.4261ec31151569db6254cfd9c5b8fcc8.jpg
#  extracting: train/images/PennPed00057_png.rf.de126d64e145765d1f3f35a2c72d6c59.jpg
#  extracting: train/images/PennPed00057_png.rf.dece3c0a592d5d574faea2a281f4c8b6.jpg
#  extracting: train/images/PennPed00058_png.rf.43c61edaa959c1911e37d0214eab2873.jpg
#  extracting: train/images/PennPed00058_png.rf.63746ce9903b20bc22acc9aebadf57ef.jpg
#  extracting: train/images/PennPed00058_png.rf.eb5447749614417468e305b786118433.jpg
#  extracting: train/images/PennPed00059_png.rf.431cebb7f15d882d51ec8f0c0c3f9aa9.jpg
#  extracting: train/images/PennPed00059_png.rf.755853ac3b3dc60dee02a7613dcca11a.jpg
#  extracting: train/images/PennPed00059_png.rf.85177aeebeaeabf721faeec83c2dca45.jpg
#  extracting: train/images/PennPed00060_png.rf.35370394912aa60fe26e1ada712f8dfa.jpg
#  extracting: train/images/PennPed00060_png.rf.9657ab79b3c58f4c74c907261acb2f05.jpg
#  extracting: train/images/PennPed00060_png.rf.c7eaf9edff9697a858de0ef60845c317.jpg
#  extracting: train/images/PennPed00061_png.rf.90fa7907c7ffbbe4be5907273edcb392.jpg
#  extracting: train/images/PennPed00061_png.rf.9121e8cff0441ab36b058a47fb3a6c37.jpg
#  extracting: train/images/PennPed00061_png.rf.d181555f9eeca7e23b5499dfed7e132a.jpg
#  extracting: train/images/PennPed00062_png.rf.021dfc6593cd4bb69139a5f4894fe5be.jpg
#  extracting: train/images/PennPed00062_png.rf.110775cedc04da7318cdf3e05cbda95b.jpg
#  extracting: train/images/PennPed00062_png.rf.1bd0512f608bce3a1b5bec00e29759e6.jpg
#  extracting: train/images/PennPed00062_png.rf.8ef4f0d0c79b52176a4a69f8af68e8ce.jpg
#  extracting: train/images/PennPed00062_png.rf.8f3717191d61371d80f24717718e941d.jpg
#  extracting: train/images/PennPed00062_png.rf.cae1be73d6490614e29b9b1d8ac906b3.jpg
#  extracting: train/images/PennPed00063_png.rf.3c657e2ac616f8df202370cbe1c271cc.jpg
#  extracting: train/images/PennPed00063_png.rf.6aa79cc5fea7daddd9187b1b0f5abef8.jpg
#  extracting: train/images/PennPed00063_png.rf.928e4c458d4809572ddab63108d507ac.jpg
#  extracting: train/images/PennPed00064_png.rf.9278dd05785e7da548294045137372f2.jpg
#  extracting: train/images/PennPed00064_png.rf.a3d43c6112d27b704b545e87bd0d7347.jpg
#  extracting: train/images/PennPed00064_png.rf.ea82517b9a596ebd88942237248c7840.jpg
#  extracting: train/images/PennPed00065_png.rf.1b647fd5cbac7091ffd24a9d9758590b.jpg
#  extracting: train/images/PennPed00065_png.rf.48a4abff0f62b9a4ab08cd7bfefce234.jpg
#  extracting: train/images/PennPed00065_png.rf.652834b2e2aa80141e2342d7a8076dac.jpg
#  extracting: train/images/PennPed00067_png.rf.60783b9ff3324b8ebbe066797943349f.jpg
#  extracting: train/images/PennPed00067_png.rf.a587ececc51e3e733696569f3277a7e0.jpg
#  extracting: train/images/PennPed00067_png.rf.d500998f8e356f149fe2fd1f49d3dd5a.jpg
#  extracting: train/images/PennPed00068_png.rf.79e9d755bc552450fe6e2d7482e4bd65.jpg
#  extracting: train/images/PennPed00068_png.rf.88a3bf5ed045b22ac18fc93f6ffa5ade.jpg
#  extracting: train/images/PennPed00068_png.rf.c2bee4b23a800aa5f862999a40e9d1c9.jpg
#  extracting: train/images/PennPed00068_png.rf.c38e5fa97e03e12999d2a9e6a6eaaf8e.jpg
#  extracting: train/images/PennPed00068_png.rf.d8e218e05f523ff87e3063ff4ee2c5ec.jpg
#  extracting: train/images/PennPed00068_png.rf.ef1f44c294601a886b65c9c46e068b38.jpg
#  extracting: train/images/PennPed00069_png.rf.2c4ab9f0adf9e4fd61693c2a05010e5f.jpg
#  extracting: train/images/PennPed00069_png.rf.6323231d81363e6d8d7f1621cad3a745.jpg
#  extracting: train/images/PennPed00069_png.rf.63c48472a86b01184fae9bb5fff624ca.jpg
#  extracting: train/images/PennPed00069_png.rf.6ecbc480b945bb00097fdc4f52f7ba14.jpg
#  extracting: train/images/PennPed00069_png.rf.e6c24e7c98115be4ec8ba96e780f1aef.jpg
#  extracting: train/images/PennPed00069_png.rf.fab5b644f978f5047935ad4bb8fdd05b.jpg
#  extracting: train/images/PennPed00070_png.rf.0959565cdbb95c36b3e6238065c608e3.jpg
#  extracting: train/images/PennPed00070_png.rf.3c06851d175648ea18fc2a1f24131f58.jpg
#  extracting: train/images/PennPed00070_png.rf.61b07cc0d810bb29fbaa6419b7076737.jpg
#  extracting: train/images/PennPed00071_png.rf.51ba74e98446b30fa72d00091eb70dd6.jpg
#  extracting: train/images/PennPed00071_png.rf.a23fcfab28882d6701e555c88be11da0.jpg
#  extracting: train/images/PennPed00071_png.rf.adb9ee41971c67152f65dc8fd64d8c3b.jpg
#  extracting: train/images/PennPed00072_png.rf.0139ce7c0ff5bcf64fcf049872adb5da.jpg
#  extracting: train/images/PennPed00072_png.rf.4874dc73a67c0c80cbfc3706fc7bf702.jpg
#  extracting: train/images/PennPed00072_png.rf.55e0e3c0d6650825eac7e1600f2828e1.jpg
#  extracting: train/images/PennPed00072_png.rf.6440ce68879abcf9ec7b37f2d017b5e6.jpg
#  extracting: train/images/PennPed00072_png.rf.b364e9ed31039e0c6d60512fe9094404.jpg
#  extracting: train/images/PennPed00072_png.rf.f2a75232a5a2bef6e69dcee147fa1eb7.jpg
#  extracting: train/images/PennPed00073_png.rf.33ca8a99017989918efd66c385ca3230.jpg
#  extracting: train/images/PennPed00073_png.rf.64137112a53f28cbfc73ff254c4cc27f.jpg
#  extracting: train/images/PennPed00073_png.rf.f33c2caf6818303f010c4d18121ab51e.jpg
#  extracting: train/images/PennPed00075_png.rf.0fa09b02cb4c010ecb8f4f588f828359.jpg
#  extracting: train/images/PennPed00075_png.rf.1738728cb9cb53439374c9e9e5d21f67.jpg
#  extracting: train/images/PennPed00075_png.rf.822a3b8ebb23c6d6cbb8b9d1a32611a6.jpg
#  extracting: train/images/PennPed00075_png.rf.8a4803aad6bbd072160335dc241fba9c.jpg
#  extracting: train/images/PennPed00075_png.rf.aa1b404f41a63b8d6eb84ca5e4ed938c.jpg
#  extracting: train/images/PennPed00075_png.rf.db04e65597bc63f76768c7c3eb7ae61b.jpg
#  extracting: train/images/PennPed00076_png.rf.516fc3d7bbc706a48096f39113464574.jpg
#  extracting: train/images/PennPed00076_png.rf.6d83ca33b363a44e461c2fd4296ca23f.jpg
#  extracting: train/images/PennPed00076_png.rf.b2da5a601f28fdcedcc4b101d079eb5d.jpg
#  extracting: train/images/PennPed00078_png.rf.3d601eb90c10da27ed3f977eda0a9fe0.jpg
#  extracting: train/images/PennPed00078_png.rf.494fb211ce6b877f06e3b7058b0a77da.jpg
#  extracting: train/images/PennPed00078_png.rf.83c4a964217a269b14437d0480ef839b.jpg
#  extracting: train/images/PennPed00079_png.rf.280b7fd01a8362680c8fa2b4ea1f461f.jpg
#  extracting: train/images/PennPed00079_png.rf.7b9d52328772fdd1139051b248fd0214.jpg
#  extracting: train/images/PennPed00079_png.rf.a183c032b1e92d5c81d71d609bf0083d.jpg
#  extracting: train/images/PennPed00079_png.rf.a4c3436338b7acd23e55bc8fd1b4afe6.jpg
#  extracting: train/images/PennPed00079_png.rf.dcbdfa2dc84477959ffc822477700a99.jpg
#  extracting: train/images/PennPed00079_png.rf.ed2155b33404f9b4b518bbbb51558ce1.jpg
#  extracting: train/images/PennPed00080_png.rf.0a43238b1865ac1395b8b5728ab4ffb4.jpg
#  extracting: train/images/PennPed00080_png.rf.3c265d7b57e4e7fcf3f892fc3910ac4b.jpg
#  extracting: train/images/PennPed00080_png.rf.4f789cdf1a612c67655e400d05d88232.jpg
#  extracting: train/images/PennPed00080_png.rf.8f846f19d89ba40dfa3280506c64c536.jpg
#  extracting: train/images/PennPed00080_png.rf.e044d41db237f1f6a253f21fe0f86684.jpg
#  extracting: train/images/PennPed00080_png.rf.f5c884482a6464b15ba1af2c5b63b481.jpg
#  extracting: train/images/PennPed00081_png.rf.0c583243c72bb53ac3bc8d542529364b.jpg
#  extracting: train/images/PennPed00081_png.rf.80ea1f79400149a572107d0c90610f1d.jpg
#  extracting: train/images/PennPed00081_png.rf.c7ca1522725f1d5039b5c94344bdc534.jpg
#  extracting: train/images/PennPed00082_png.rf.20d6215441f4df24ded4aac24e1708a6.jpg
#  extracting: train/images/PennPed00082_png.rf.2977fc0a66a37274ca56b6bfe657f6b5.jpg
#  extracting: train/images/PennPed00082_png.rf.3ca7cd6d719a50b5e2676c81b53bc712.jpg
#  extracting: train/images/PennPed00082_png.rf.535493d2066cfd9009084e672dec11d3.jpg
#  extracting: train/images/PennPed00082_png.rf.926ace0819114944aa9bffe0bb6e233c.jpg
#  extracting: train/images/PennPed00082_png.rf.c30177047b9a2e9d0f5f51c54f024e1d.jpg
#  extracting: train/images/PennPed00084_png.rf.3ad41361b857f15d3193f5c3afd869d5.jpg
#  extracting: train/images/PennPed00084_png.rf.a0e05fd2638f1052ec773ae40a2ed846.jpg
#  extracting: train/images/PennPed00084_png.rf.a5cdee9a527d3a0d6e63e02be20a9385.jpg
#  extracting: train/images/PennPed00084_png.rf.ad5dcbdd5d8faf458292ec82eda44859.jpg
#  extracting: train/images/PennPed00084_png.rf.f7bb34253788150fdfea57a0a64f8212.jpg
#  extracting: train/images/PennPed00084_png.rf.ff4e2d8b150f443aa036fcec45e226f1.jpg
#  extracting: train/images/PennPed00085_png.rf.b0f2ee49f9957a1c40408f09fc7fcb44.jpg
#  extracting: train/images/PennPed00085_png.rf.d288d31a8314ca23660b49b7a4f251d6.jpg
#  extracting: train/images/PennPed00085_png.rf.e76bcfd6578062b220944920e3b7d826.jpg
#  extracting: train/images/PennPed00086_png.rf.3e912c05d3cf75621f35cad30fe19c3d.jpg
#  extracting: train/images/PennPed00086_png.rf.42646d744a0110b0716ad9aa12a9803f.jpg
#  extracting: train/images/PennPed00086_png.rf.fde059bfc239dab761604627ddc82153.jpg
#  extracting: train/images/PennPed00087_png.rf.0ed7c267eb175a5291a3d467fe85e5d1.jpg
#  extracting: train/images/PennPed00087_png.rf.10ec553bcc71ccf9c232d486ff02e853.jpg
#  extracting: train/images/PennPed00087_png.rf.25875ab8387811fa117fd796cd5d3e41.jpg
#  extracting: train/images/PennPed00087_png.rf.283454564d756aff6c199192a6111c20.jpg
#  extracting: train/images/PennPed00087_png.rf.2c8f91f8b53639c8aa81d79171cd45dc.jpg
#  extracting: train/images/PennPed00087_png.rf.48a575695eb82cdcacacae5965353590.jpg
#  extracting: train/images/PennPed00088_png.rf.06ba6ffba86d3ed6f91895b925335655.jpg
#  extracting: train/images/PennPed00088_png.rf.51ba44eb35928a3e1e2ffed588900d85.jpg
#  extracting: train/images/PennPed00088_png.rf.efa7c1cc36618e81319f921892162b61.jpg
#  extracting: train/images/PennPed00089_png.rf.29ff18486a16d3fa5f7d2604721e1420.jpg
#  extracting: train/images/PennPed00089_png.rf.8602768203622a3b0ef66d62441fe1d5.jpg
#  extracting: train/images/PennPed00089_png.rf.d3e8fb78f89894f2b0e812d71f395adc.jpg
#  extracting: train/images/PennPed00091_png.rf.50071a8b7c8f6eb32dbf96bfbc938c4e.jpg
#  extracting: train/images/PennPed00091_png.rf.a107e639fc279f7bae545ee1f3cde532.jpg
#  extracting: train/images/PennPed00091_png.rf.c2fc468fb34532189cbc98185bb76261.jpg
#  extracting: train/images/PennPed00093_png.rf.3e94051c6e403a34c139f4265a17b7e7.jpg
#  extracting: train/images/PennPed00093_png.rf.878c9593491337b69f10cee5d34a7ce6.jpg
#  extracting: train/images/PennPed00093_png.rf.cabd9b6928fb256a078e2c9eaff749bc.jpg
#  extracting: train/images/PennPed00094_png.rf.05a2a18e401adb1b28d8d3d94415c9fa.jpg
#  extracting: train/images/PennPed00094_png.rf.52d1898717c4dbe49685c6503c598cae.jpg
#  extracting: train/images/PennPed00094_png.rf.6ac97dd3e512560883484f68d4823b0c.jpg
#  extracting: train/images/PennPed00094_png.rf.79d5cb2bbb1b3a6010881d136800a039.jpg
#  extracting: train/images/PennPed00094_png.rf.d554a94fdcd4b67671ed5ca914282ed5.jpg
#  extracting: train/images/PennPed00094_png.rf.dde7b67c2b2e062b863bfd1915355acf.jpg
#  extracting: train/images/PennPed00095_png.rf.351347428f0fea4e8edffc02114c6dc9.jpg
#  extracting: train/images/PennPed00095_png.rf.a825c6ea9f1a46bf2e9e05edcbb2cb4f.jpg
#  extracting: train/images/PennPed00095_png.rf.fef6b859ef98f250def46b69e1ee0e7a.jpg
#    creating: train/labels/
#  extracting: train/labels/FudanPed00001_png.rf.0b11b2eb66b57ef60f7f906ca2e481aa.txt
#  extracting: train/labels/FudanPed00001_png.rf.10e9884f4e7f83352c085397258b0d7f.txt
#  extracting: train/labels/FudanPed00001_png.rf.5cc7ef7cd152486910e8f8c0d69738f7.txt
#  extracting: train/labels/FudanPed00004_png.rf.78800ccc4be3ce4cb4e61e6b3d87eb96.txt
#  extracting: train/labels/FudanPed00004_png.rf.796c028e4e9f5c1f5fa2920700871ef6.txt
#  extracting: train/labels/FudanPed00004_png.rf.ef4b98c0570a674720290395b00fb1be.txt
#  extracting: train/labels/FudanPed00007_png.rf.280cfc2a1aed351b81899a6c1c5f243b.txt
#  extracting: train/labels/FudanPed00007_png.rf.753bd5996ea571504eb06b3c6191a9ba.txt
#  extracting: train/labels/FudanPed00007_png.rf.d886a78277a7fb41bdf3e4292ed64cd1.txt
#  extracting: train/labels/FudanPed00008_png.rf.637bbf23811ce3ba2a04ff88f565405e.txt
#  extracting: train/labels/FudanPed00008_png.rf.b882fcb88d3cd22d45aa960308819d40.txt
#  extracting: train/labels/FudanPed00008_png.rf.f5e8c284b153dbb9e7164c889c1f3474.txt
#  extracting: train/labels/FudanPed00009_png.rf.22d360630aedca375737ff22f4e91fe1.txt
#  extracting: train/labels/FudanPed00009_png.rf.38c85f85067fd52f6e691ce900ac4257.txt
#  extracting: train/labels/FudanPed00009_png.rf.5603d733276a0fe801468dee74bbb43f.txt
#  extracting: train/labels/FudanPed00011_png.rf.200a309f17072acb0199da7d52378438.txt
#  extracting: train/labels/FudanPed00011_png.rf.91dba1da76d673853706df99d44fbbfd.txt
#  extracting: train/labels/FudanPed00011_png.rf.d60e21a576a22764f13efd8b13bc5a8f.txt
#  extracting: train/labels/FudanPed00012_png.rf.006daf90bf226801db2080dd29eca4b4.txt
#  extracting: train/labels/FudanPed00012_png.rf.1e62009154e66f2392f67ea06d33af21.txt
#  extracting: train/labels/FudanPed00012_png.rf.ec7360d1c48dcba6cdd8130bb08ae053.txt
#  extracting: train/labels/FudanPed00013_png.rf.3374974743d20582c1abe3dbbab9eebc.txt
#  extracting: train/labels/FudanPed00013_png.rf.381cf3ec71c843204be4e18f2e69c4e1.txt
#  extracting: train/labels/FudanPed00013_png.rf.85f20ff6e4ecf962f3b5c2b96d6ae041.txt
#  extracting: train/labels/FudanPed00014_png.rf.17868129c8e5c2a4933a710726400ee4.txt
#  extracting: train/labels/FudanPed00014_png.rf.79fce8f3d7cbdcfe9d09c82ce7314cfc.txt
#  extracting: train/labels/FudanPed00014_png.rf.992253e01472b9d00ff2bd17240c3277.txt
#  extracting: train/labels/FudanPed00015_png.rf.1cf283d2b93254d6f44ab5dea5cc5ef1.txt
#  extracting: train/labels/FudanPed00015_png.rf.878b681ca89ab37ba5b72dc06c47842d.txt
#  extracting: train/labels/FudanPed00015_png.rf.d297cd14a350a9e4ab27e8cbebf37177.txt
#  extracting: train/labels/FudanPed00016_png.rf.3878288d25f1d881a94c67945f1359b5.txt
#  extracting: train/labels/FudanPed00016_png.rf.50e52fc3bbcf082b756574903e4f232b.txt
#  extracting: train/labels/FudanPed00016_png.rf.a67e8a86a31892c081261828e1f0c59f.txt
#  extracting: train/labels/FudanPed00017_png.rf.148c42bac6d021b9e55e37c187a168e8.txt
#  extracting: train/labels/FudanPed00017_png.rf.daf2624f3dc637b7386341b385b780c5.txt
#  extracting: train/labels/FudanPed00017_png.rf.f9c35067310be22d6cd864cdd9c857bd.txt
#  extracting: train/labels/FudanPed00019_png.rf.9d7d03f08082a588042107632bcf6122.txt
#  extracting: train/labels/FudanPed00019_png.rf.c875981439ab0a98c501ce6c9615c07a.txt
#  extracting: train/labels/FudanPed00019_png.rf.e9aff36d905dc8996b22b90853c7ecdb.txt
#  extracting: train/labels/FudanPed00022_png.rf.2b4bf43b82cf36d5937e7ef85de1d99e.txt
#  extracting: train/labels/FudanPed00022_png.rf.5fcadf12169573bd795163bb74506610.txt
#  extracting: train/labels/FudanPed00022_png.rf.5ff5434f7e3ec9839eb605a5e2bfcda6.txt
#  extracting: train/labels/FudanPed00023_png.rf.5195ce7245e7c4e3e298f8c2d8542585.txt
#  extracting: train/labels/FudanPed00023_png.rf.dfc9dac7f4bda538cc4cf40aff9ec0c9.txt
#  extracting: train/labels/FudanPed00023_png.rf.ff580e66654ec9a25f60787c34a8d393.txt
#  extracting: train/labels/FudanPed00024_png.rf.14d70d97fbd18cf6615c96eb5f4358b8.txt
#  extracting: train/labels/FudanPed00024_png.rf.3ad535b496b3adac7ce2f51f009163fd.txt
#  extracting: train/labels/FudanPed00024_png.rf.9ed2e32aa60192c7b4403b39020bcfb9.txt
#  extracting: train/labels/FudanPed00027_png.rf.4cfe371acca20c5e98ddc55da460f362.txt
#  extracting: train/labels/FudanPed00027_png.rf.6581326ebb90f635be8e1a7ef8b8c503.txt
#  extracting: train/labels/FudanPed00027_png.rf.88fe0a887675f423e4aa20ab78521a66.txt
#  extracting: train/labels/FudanPed00032_png.rf.838565d53d67ce43956c3392fb338576.txt
#  extracting: train/labels/FudanPed00032_png.rf.d746194d201e2725b53cad965b6f472d.txt
#  extracting: train/labels/FudanPed00032_png.rf.dce79f89c609f7cc1a7a1eefbad6cfa7.txt
#  extracting: train/labels/FudanPed00033_png.rf.2f69f8dad9bc6f7afeab94ea05291698.txt
#  extracting: train/labels/FudanPed00033_png.rf.5c3b834cdf59a19b03e6684f3e14bb57.txt
#  extracting: train/labels/FudanPed00033_png.rf.5e750f7c7c231a90b6beb5687e8ee877.txt
#  extracting: train/labels/FudanPed00035_png.rf.2371e45a74296c2fb8233e3234c7a874.txt
#  extracting: train/labels/FudanPed00035_png.rf.5488089fba59c4d5db4cd3e882008981.txt
#  extracting: train/labels/FudanPed00035_png.rf.d7bdc041b1b5b28d3c3e71a827e5bd86.txt
#  extracting: train/labels/FudanPed00036_png.rf.1bba6015dfeba4ca34ae11e1e2ce6dcc.txt
#  extracting: train/labels/FudanPed00036_png.rf.7a147910c20db8b7ee4184881652e2a5.txt
#  extracting: train/labels/FudanPed00036_png.rf.f23e7b4316af19066f8553991be14431.txt
#  extracting: train/labels/FudanPed00037_png.rf.627fbc9be70fd6839720ed05b9e43fd7.txt
#  extracting: train/labels/FudanPed00037_png.rf.b2d83447611576b22dbe2f3dbe688eb8.txt
#  extracting: train/labels/FudanPed00037_png.rf.e10ce76823da95a17c7ef83bbca32f77.txt
#  extracting: train/labels/FudanPed00038_png.rf.08bc230b814f856c7bec407b87c15e85.txt
#  extracting: train/labels/FudanPed00038_png.rf.5fe763852ae968e1b3790db0cedc3810.txt
#  extracting: train/labels/FudanPed00038_png.rf.890c8b7f640b89ef122d56294cae2795.txt
#  extracting: train/labels/FudanPed00039_png.rf.445dbe3394a1b20e24b6f1e4924f9766.txt
#  extracting: train/labels/FudanPed00039_png.rf.4972662d410156a0f5b497938f75ef0d.txt
#  extracting: train/labels/FudanPed00039_png.rf.7216b9e69343b9318841e678d2d945b2.txt
#  extracting: train/labels/FudanPed00040_png.rf.693df3b39d030da36862e5f713fd2cc5.txt
#  extracting: train/labels/FudanPed00040_png.rf.6d95619796a050db33cb892b845dd33f.txt
#  extracting: train/labels/FudanPed00040_png.rf.8331eb143f19406a538b5785f33ec198.txt
#  extracting: train/labels/FudanPed00041_png.rf.376a816c74f2e4adda69921a28d741e8.txt
#  extracting: train/labels/FudanPed00041_png.rf.9f82a8d0642ed4189a34f80db6516e5a.txt
#  extracting: train/labels/FudanPed00041_png.rf.d8604cfd0dc5f9bee979418fd2d681db.txt
#  extracting: train/labels/FudanPed00043_png.rf.2352510f1810d8aaf75d7dd55bda626a.txt
#  extracting: train/labels/FudanPed00043_png.rf.5f3ebecc45b805f3953e83552bbb4599.txt
#  extracting: train/labels/FudanPed00043_png.rf.cffcacc00ab5abb1d68e565d47083684.txt
#  extracting: train/labels/FudanPed00044_png.rf.3559ea1418590460b52c8b919d7ba38f.txt
#  extracting: train/labels/FudanPed00044_png.rf.95778e750b7fdb562e4bc30be10d06e7.txt
#  extracting: train/labels/FudanPed00044_png.rf.e17ce025387ebed42eef165781ba8caa.txt
#  extracting: train/labels/FudanPed00045_png.rf.57256537000ea7bd96acde1c4bd6d71c.txt
#  extracting: train/labels/FudanPed00045_png.rf.e3e9f658990517618fb70aee91f198fc.txt
#  extracting: train/labels/FudanPed00045_png.rf.e4844b67b27ae792c6521ab93ef698e4.txt
#  extracting: train/labels/FudanPed00046_png.rf.705365e4ea82c8fa27b801050e7f2a9c.txt
#  extracting: train/labels/FudanPed00046_png.rf.b0ef058ebea91720ee5fba32eb91ab17.txt
#  extracting: train/labels/FudanPed00046_png.rf.c912acd4aef91e3025c5ea28e093fe89.txt
#  extracting: train/labels/FudanPed00047_png.rf.581d9cfbb0e9fb62fb858dad4727b07a.txt
#  extracting: train/labels/FudanPed00047_png.rf.6f606144796fd981f03c4f2a3420b295.txt
#  extracting: train/labels/FudanPed00047_png.rf.9578e9cc09ac1d4e1c1704c2289d3df9.txt
#  extracting: train/labels/FudanPed00050_png.rf.9de726e33a52c36838b832d51ed5e412.txt
#  extracting: train/labels/FudanPed00050_png.rf.a77fa5c9182b1d2e91d8e846d8baad76.txt
#  extracting: train/labels/FudanPed00050_png.rf.d5b1ae4d78d40739d229f326c3fc07e8.txt
#  extracting: train/labels/FudanPed00051_png.rf.14fd53cdda54e6c48c61b019485bf0f5.txt
#  extracting: train/labels/FudanPed00051_png.rf.24456458b2e5e912436582e84bbd37b2.txt
#  extracting: train/labels/FudanPed00051_png.rf.2e5cabddcf3387f4e93e493e268c683c.txt
#  extracting: train/labels/FudanPed00053_png.rf.01517c76163641d21b149e357491f09f.txt
#  extracting: train/labels/FudanPed00053_png.rf.7844d906e5d8474456e31148e8306690.txt
# ...
#  extracting: train/labels/PennPed00063_png.rf.6aa79cc5fea7daddd9187b1b0f5abef8.txt
#  extracting: train/labels/PennPed00063_png.rf.928e4c458d4809572ddab63108d507ac.txt
#  extracting: train/labels/PennPed00064_png.rf.9278dd05785e7da548294045137372f2.txt
#  extracting: train/labels/PennPed00064_png.rf.a3d43c6112d27b704b545e87bd0d7347.txt
#  extracting: train/labels/PennPed00064_png.rf.ea82517b9a596ebd88942237248c7840.txt
#  extracting: train/labels/PennPed00065_png.rf.1b647fd5cbac7091ffd24a9d9758590b.txt
#  extracting: train/labels/PennPed00065_png.rf.48a4abff0f62b9a4ab08cd7bfefce234.txt
#  extracting: train/labels/PennPed00065_png.rf.652834b2e2aa80141e2342d7a8076dac.txt
#  extracting: train/labels/PennPed00067_png.rf.60783b9ff3324b8ebbe066797943349f.txt
#  extracting: train/labels/PennPed00067_png.rf.a587ececc51e3e733696569f3277a7e0.txt
#  extracting: train/labels/PennPed00067_png.rf.d500998f8e356f149fe2fd1f49d3dd5a.txt
#  extracting: train/labels/PennPed00068_png.rf.79e9d755bc552450fe6e2d7482e4bd65.txt
#  extracting: train/labels/PennPed00068_png.rf.88a3bf5ed045b22ac18fc93f6ffa5ade.txt
#  extracting: train/labels/PennPed00068_png.rf.c2bee4b23a800aa5f862999a40e9d1c9.txt
#  extracting: train/labels/PennPed00068_png.rf.c38e5fa97e03e12999d2a9e6a6eaaf8e.txt
#  extracting: train/labels/PennPed00068_png.rf.d8e218e05f523ff87e3063ff4ee2c5ec.txt
#  extracting: train/labels/PennPed00068_png.rf.ef1f44c294601a886b65c9c46e068b38.txt
#  extracting: train/labels/PennPed00069_png.rf.2c4ab9f0adf9e4fd61693c2a05010e5f.txt
#  extracting: train/labels/PennPed00069_png.rf.6323231d81363e6d8d7f1621cad3a745.txt
#  extracting: train/labels/PennPed00069_png.rf.63c48472a86b01184fae9bb5fff624ca.txt
#  extracting: train/labels/PennPed00069_png.rf.6ecbc480b945bb00097fdc4f52f7ba14.txt
#  extracting: train/labels/PennPed00069_png.rf.e6c24e7c98115be4ec8ba96e780f1aef.txt
#  extracting: train/labels/PennPed00069_png.rf.fab5b644f978f5047935ad4bb8fdd05b.txt
#  extracting: train/labels/PennPed00070_png.rf.0959565cdbb95c36b3e6238065c608e3.txt
#  extracting: train/labels/PennPed00070_png.rf.3c06851d175648ea18fc2a1f24131f58.txt
#  extracting: train/labels/PennPed00070_png.rf.61b07cc0d810bb29fbaa6419b7076737.txt
#  extracting: train/labels/PennPed00071_png.rf.51ba74e98446b30fa72d00091eb70dd6.txt
#  extracting: train/labels/PennPed00071_png.rf.a23fcfab28882d6701e555c88be11da0.txt
#  extracting: train/labels/PennPed00071_png.rf.adb9ee41971c67152f65dc8fd64d8c3b.txt
#  extracting: train/labels/PennPed00072_png.rf.0139ce7c0ff5bcf64fcf049872adb5da.txt
#  extracting: train/labels/PennPed00072_png.rf.4874dc73a67c0c80cbfc3706fc7bf702.txt
#  extracting: train/labels/PennPed00072_png.rf.55e0e3c0d6650825eac7e1600f2828e1.txt
#  extracting: train/labels/PennPed00072_png.rf.6440ce68879abcf9ec7b37f2d017b5e6.txt
#  extracting: train/labels/PennPed00072_png.rf.b364e9ed31039e0c6d60512fe9094404.txt
#  extracting: train/labels/PennPed00072_png.rf.f2a75232a5a2bef6e69dcee147fa1eb7.txt
#  extracting: train/labels/PennPed00073_png.rf.33ca8a99017989918efd66c385ca3230.txt
#  extracting: train/labels/PennPed00073_png.rf.64137112a53f28cbfc73ff254c4cc27f.txt
#  extracting: train/labels/PennPed00073_png.rf.f33c2caf6818303f010c4d18121ab51e.txt
#  extracting: train/labels/PennPed00075_png.rf.0fa09b02cb4c010ecb8f4f588f828359.txt
#  extracting: train/labels/PennPed00075_png.rf.1738728cb9cb53439374c9e9e5d21f67.txt
#  extracting: train/labels/PennPed00075_png.rf.822a3b8ebb23c6d6cbb8b9d1a32611a6.txt
#  extracting: train/labels/PennPed00075_png.rf.8a4803aad6bbd072160335dc241fba9c.txt
#  extracting: train/labels/PennPed00075_png.rf.aa1b404f41a63b8d6eb84ca5e4ed938c.txt
#  extracting: train/labels/PennPed00075_png.rf.db04e65597bc63f76768c7c3eb7ae61b.txt
#  extracting: train/labels/PennPed00076_png.rf.516fc3d7bbc706a48096f39113464574.txt
#  extracting: train/labels/PennPed00076_png.rf.6d83ca33b363a44e461c2fd4296ca23f.txt
#  extracting: train/labels/PennPed00076_png.rf.b2da5a601f28fdcedcc4b101d079eb5d.txt
#  extracting: train/labels/PennPed00078_png.rf.3d601eb90c10da27ed3f977eda0a9fe0.txt
#  extracting: train/labels/PennPed00078_png.rf.494fb211ce6b877f06e3b7058b0a77da.txt
#  extracting: train/labels/PennPed00078_png.rf.83c4a964217a269b14437d0480ef839b.txt
#  extracting: train/labels/PennPed00079_png.rf.280b7fd01a8362680c8fa2b4ea1f461f.txt
#  extracting: train/labels/PennPed00079_png.rf.7b9d52328772fdd1139051b248fd0214.txt
#  extracting: train/labels/PennPed00079_png.rf.a183c032b1e92d5c81d71d609bf0083d.txt
#  extracting: train/labels/PennPed00079_png.rf.a4c3436338b7acd23e55bc8fd1b4afe6.txt
#  extracting: train/labels/PennPed00079_png.rf.dcbdfa2dc84477959ffc822477700a99.txt
#  extracting: train/labels/PennPed00079_png.rf.ed2155b33404f9b4b518bbbb51558ce1.txt
#  extracting: train/labels/PennPed00080_png.rf.0a43238b1865ac1395b8b5728ab4ffb4.txt
#  extracting: train/labels/PennPed00080_png.rf.3c265d7b57e4e7fcf3f892fc3910ac4b.txt
#  extracting: train/labels/PennPed00080_png.rf.4f789cdf1a612c67655e400d05d88232.txt
#  extracting: train/labels/PennPed00080_png.rf.8f846f19d89ba40dfa3280506c64c536.txt
#  extracting: train/labels/PennPed00080_png.rf.e044d41db237f1f6a253f21fe0f86684.txt
#  extracting: train/labels/PennPed00080_png.rf.f5c884482a6464b15ba1af2c5b63b481.txt
#  extracting: train/labels/PennPed00081_png.rf.0c583243c72bb53ac3bc8d542529364b.txt
#  extracting: train/labels/PennPed00081_png.rf.80ea1f79400149a572107d0c90610f1d.txt
#  extracting: train/labels/PennPed00081_png.rf.c7ca1522725f1d5039b5c94344bdc534.txt
#  extracting: train/labels/PennPed00082_png.rf.20d6215441f4df24ded4aac24e1708a6.txt
#  extracting: train/labels/PennPed00082_png.rf.2977fc0a66a37274ca56b6bfe657f6b5.txt
#  extracting: train/labels/PennPed00082_png.rf.3ca7cd6d719a50b5e2676c81b53bc712.txt
#  extracting: train/labels/PennPed00082_png.rf.535493d2066cfd9009084e672dec11d3.txt
#  extracting: train/labels/PennPed00082_png.rf.926ace0819114944aa9bffe0bb6e233c.txt
#  extracting: train/labels/PennPed00082_png.rf.c30177047b9a2e9d0f5f51c54f024e1d.txt
#  extracting: train/labels/PennPed00084_png.rf.3ad41361b857f15d3193f5c3afd869d5.txt
#  extracting: train/labels/PennPed00084_png.rf.a0e05fd2638f1052ec773ae40a2ed846.txt
#  extracting: train/labels/PennPed00084_png.rf.a5cdee9a527d3a0d6e63e02be20a9385.txt
#  extracting: train/labels/PennPed00084_png.rf.ad5dcbdd5d8faf458292ec82eda44859.txt
#  extracting: train/labels/PennPed00084_png.rf.f7bb34253788150fdfea57a0a64f8212.txt
#  extracting: train/labels/PennPed00084_png.rf.ff4e2d8b150f443aa036fcec45e226f1.txt
#  extracting: train/labels/PennPed00085_png.rf.b0f2ee49f9957a1c40408f09fc7fcb44.txt
#  extracting: train/labels/PennPed00085_png.rf.d288d31a8314ca23660b49b7a4f251d6.txt
#  extracting: train/labels/PennPed00085_png.rf.e76bcfd6578062b220944920e3b7d826.txt
#  extracting: train/labels/PennPed00086_png.rf.3e912c05d3cf75621f35cad30fe19c3d.txt
#  extracting: train/labels/PennPed00086_png.rf.42646d744a0110b0716ad9aa12a9803f.txt
#  extracting: train/labels/PennPed00086_png.rf.fde059bfc239dab761604627ddc82153.txt
#  extracting: train/labels/PennPed00087_png.rf.0ed7c267eb175a5291a3d467fe85e5d1.txt
#  extracting: train/labels/PennPed00087_png.rf.10ec553bcc71ccf9c232d486ff02e853.txt
#  extracting: train/labels/PennPed00087_png.rf.25875ab8387811fa117fd796cd5d3e41.txt
#  extracting: train/labels/PennPed00087_png.rf.283454564d756aff6c199192a6111c20.txt
#  extracting: train/labels/PennPed00087_png.rf.2c8f91f8b53639c8aa81d79171cd45dc.txt
#  extracting: train/labels/PennPed00087_png.rf.48a575695eb82cdcacacae5965353590.txt
#  extracting: train/labels/PennPed00088_png.rf.06ba6ffba86d3ed6f91895b925335655.txt
#  extracting: train/labels/PennPed00088_png.rf.51ba44eb35928a3e1e2ffed588900d85.txt
#  extracting: train/labels/PennPed00088_png.rf.efa7c1cc36618e81319f921892162b61.txt
#  extracting: train/labels/PennPed00089_png.rf.29ff18486a16d3fa5f7d2604721e1420.txt
#  extracting: train/labels/PennPed00089_png.rf.8602768203622a3b0ef66d62441fe1d5.txt
#  extracting: train/labels/PennPed00089_png.rf.d3e8fb78f89894f2b0e812d71f395adc.txt
#  extracting: train/labels/PennPed00091_png.rf.50071a8b7c8f6eb32dbf96bfbc938c4e.txt
#  extracting: train/labels/PennPed00091_png.rf.a107e639fc279f7bae545ee1f3cde532.txt
#  extracting: train/labels/PennPed00091_png.rf.c2fc468fb34532189cbc98185bb76261.txt
#  extracting: train/labels/PennPed00093_png.rf.3e94051c6e403a34c139f4265a17b7e7.txt
#  extracting: train/labels/PennPed00093_png.rf.878c9593491337b69f10cee5d34a7ce6.txt
#  extracting: train/labels/PennPed00093_png.rf.cabd9b6928fb256a078e2c9eaff749bc.txt
#  extracting: train/labels/PennPed00094_png.rf.05a2a18e401adb1b28d8d3d94415c9fa.txt
#  extracting: train/labels/PennPed00094_png.rf.52d1898717c4dbe49685c6503c598cae.txt
#  extracting: train/labels/PennPed00094_png.rf.6ac97dd3e512560883484f68d4823b0c.txt
#  extracting: train/labels/PennPed00094_png.rf.79d5cb2bbb1b3a6010881d136800a039.txt
#  extracting: train/labels/PennPed00094_png.rf.d554a94fdcd4b67671ed5ca914282ed5.txt
#  extracting: train/labels/PennPed00094_png.rf.dde7b67c2b2e062b863bfd1915355acf.txt
#  extracting: train/labels/PennPed00095_png.rf.351347428f0fea4e8edffc02114c6dc9.txt
#  extracting: train/labels/PennPed00095_png.rf.a825c6ea9f1a46bf2e9e05edcbb2cb4f.txt
#  extracting: train/labels/PennPed00095_png.rf.fef6b859ef98f250def46b69e1ee0e7a.txt
#    creating: valid/
#    creating: valid/images/
#  extracting: valid/images/FudanPed00006_png.rf.f7ea8e263c72ce792a88f8e47f2ac109.jpg
#  extracting: valid/images/FudanPed00010_png.rf.52254a34f6a3ea131d7095d66c17bf3c.jpg
#  extracting: valid/images/FudanPed00018_png.rf.df719fbef1f5d5b5cae0719ce22cc104.jpg
#  extracting: valid/images/FudanPed00020_png.rf.b95d40941db0b8a93770e77722a1c505.jpg
#  extracting: valid/images/FudanPed00021_png.rf.8b71ccf33ffbe1d34570610bef96505e.jpg
#  extracting: valid/images/FudanPed00025_png.rf.8ea200a51fc66123afb23309017ebb76.jpg
#  extracting: valid/images/FudanPed00028_png.rf.05b678d19e396fafd2e5766f8f89b0aa.jpg
#  extracting: valid/images/FudanPed00030_png.rf.235fa45568152b5f8dd022a903124617.jpg
#  extracting: valid/images/FudanPed00031_png.rf.93499ebf3d95765ca87a67f02bfa53a5.jpg
#  extracting: valid/images/FudanPed00034_png.rf.dfab518fa4632cb4ecdb1412241c4a8e.jpg
#  extracting: valid/images/FudanPed00048_png.rf.b25558ef91a7c24ee01c1d307fa9cc71.jpg
#  extracting: valid/images/FudanPed00049_png.rf.31382f961276be6f7ec790ca98872ed0.jpg
#  extracting: valid/images/FudanPed00052_png.rf.1514241f15c1c866715c9cc5f6d72f40.jpg
#  extracting: valid/images/FudanPed00055_png.rf.7632e770af284b62b4e6bb18f7b13981.jpg
#  extracting: valid/images/FudanPed00056_png.rf.90c9b1b6c6b913084c2a159db30207de.jpg
#  extracting: valid/images/FudanPed00068_png.rf.ce4eb9e05a17cbeec399291ba559cb64.jpg
#  extracting: valid/images/FudanPed00069_png.rf.5a388d40124c42eb1ee038806921170c.jpg
#  extracting: valid/images/FudanPed00070_png.rf.adc3c2b8ec50426ff4368e242ad8e420.jpg
#  extracting: valid/images/FudanPed00073_png.rf.f23c6b8ef9729071a5e08e84c247e056.jpg
#  extracting: valid/images/FudanPed00074_png.rf.7e119ad2f3e7bbe512b289f0e6390042.jpg
#  extracting: valid/images/PennPed00001_png.rf.bce39faae99b48321e4e00fd288d4966.jpg
#  extracting: valid/images/PennPed00026_png.rf.cf01c54544872252b6332a0240360548.jpg
#  extracting: valid/images/PennPed00039_png.rf.1f2e28bc5b06833949405c7ed25b5e27.jpg
#  extracting: valid/images/PennPed00040_png.rf.2605688b9d0953dabbcd6d4445d5ba89.jpg
#  extracting: valid/images/PennPed00041_png.rf.eaa34feb1a027484dcd0be5874e2ca67.jpg
#  extracting: valid/images/PennPed00043_png.rf.603a9582cd09d7ba12077ff6e033155b.jpg
#  extracting: valid/images/PennPed00047_png.rf.8684df2636749bc6293646ae8176078d.jpg
#  extracting: valid/images/PennPed00051_png.rf.47e740c1bee884ada57f415f3e09ddb5.jpg
#  extracting: valid/images/PennPed00053_png.rf.129dfce46c3792162a05f7f3e0bf4ec2.jpg
#  extracting: valid/images/PennPed00055_png.rf.f65ee980b0e94d066e5a3287afe2e976.jpg
#  extracting: valid/images/PennPed00058_png.rf.6ae0fbd987dea166a4eff502ad595038.jpg
#  extracting: valid/images/PennPed00063_png.rf.e9f3d4186671933751b0c431cc1bfb0c.jpg
#  extracting: valid/images/PennPed00073_png.rf.3aef0525fbe7935e6645332159b8dda7.jpg
#  extracting: valid/images/PennPed00076_png.rf.763a7755bc6ebe25a500ae3feedf5956.jpg
#  extracting: valid/images/PennPed00077_png.rf.bd8ff1cd103edb4bab0dd9c32406c1ad.jpg
#  extracting: valid/images/PennPed00077_png.rf.df4fd05a84115a25a619f47f3bcd1b0c.jpg
#  extracting: valid/images/PennPed00088_png.rf.be7892bcd0757c16486554e571e1d4c5.jpg
#  extracting: valid/images/PennPed00090_png.rf.b35d52780091e9ab6b5472b4fec6cfa2.jpg
#    creating: valid/labels/
#  extracting: valid/labels/FudanPed00006_png.rf.f7ea8e263c72ce792a88f8e47f2ac109.txt
#  extracting: valid/labels/FudanPed00010_png.rf.52254a34f6a3ea131d7095d66c17bf3c.txt
#  extracting: valid/labels/FudanPed00018_png.rf.df719fbef1f5d5b5cae0719ce22cc104.txt
#  extracting: valid/labels/FudanPed00020_png.rf.b95d40941db0b8a93770e77722a1c505.txt
#  extracting: valid/labels/FudanPed00021_png.rf.8b71ccf33ffbe1d34570610bef96505e.txt
#  extracting: valid/labels/FudanPed00025_png.rf.8ea200a51fc66123afb23309017ebb76.txt
#  extracting: valid/labels/FudanPed00028_png.rf.05b678d19e396fafd2e5766f8f89b0aa.txt
#  extracting: valid/labels/FudanPed00030_png.rf.235fa45568152b5f8dd022a903124617.txt
#  extracting: valid/labels/FudanPed00031_png.rf.93499ebf3d95765ca87a67f02bfa53a5.txt
#  extracting: valid/labels/FudanPed00034_png.rf.dfab518fa4632cb4ecdb1412241c4a8e.txt
#  extracting: valid/labels/FudanPed00048_png.rf.b25558ef91a7c24ee01c1d307fa9cc71.txt
#  extracting: valid/labels/FudanPed00049_png.rf.31382f961276be6f7ec790ca98872ed0.txt
#  extracting: valid/labels/FudanPed00052_png.rf.1514241f15c1c866715c9cc5f6d72f40.txt
#  extracting: valid/labels/FudanPed00055_png.rf.7632e770af284b62b4e6bb18f7b13981.txt
#  extracting: valid/labels/FudanPed00056_png.rf.90c9b1b6c6b913084c2a159db30207de.txt
#  extracting: valid/labels/FudanPed00068_png.rf.ce4eb9e05a17cbeec399291ba559cb64.txt
#  extracting: valid/labels/FudanPed00069_png.rf.5a388d40124c42eb1ee038806921170c.txt
#  extracting: valid/labels/FudanPed00070_png.rf.adc3c2b8ec50426ff4368e242ad8e420.txt
#  extracting: valid/labels/FudanPed00073_png.rf.f23c6b8ef9729071a5e08e84c247e056.txt
#  extracting: valid/labels/FudanPed00074_png.rf.7e119ad2f3e7bbe512b289f0e6390042.txt
#  extracting: valid/labels/PennPed00001_png.rf.bce39faae99b48321e4e00fd288d4966.txt
#  extracting: valid/labels/PennPed00026_png.rf.cf01c54544872252b6332a0240360548.txt
#  extracting: valid/labels/PennPed00039_png.rf.1f2e28bc5b06833949405c7ed25b5e27.txt
#  extracting: valid/labels/PennPed00040_png.rf.2605688b9d0953dabbcd6d4445d5ba89.txt
#  extracting: valid/labels/PennPed00041_png.rf.eaa34feb1a027484dcd0be5874e2ca67.txt
#  extracting: valid/labels/PennPed00043_png.rf.603a9582cd09d7ba12077ff6e033155b.txt
#  extracting: valid/labels/PennPed00047_png.rf.8684df2636749bc6293646ae8176078d.txt
#  extracting: valid/labels/PennPed00051_png.rf.47e740c1bee884ada57f415f3e09ddb5.txt
#  extracting: valid/labels/PennPed00053_png.rf.129dfce46c3792162a05f7f3e0bf4ec2.txt
#  extracting: valid/labels/PennPed00055_png.rf.f65ee980b0e94d066e5a3287afe2e976.txt
#  extracting: valid/labels/PennPed00058_png.rf.6ae0fbd987dea166a4eff502ad595038.txt
#  extracting: valid/labels/PennPed00063_png.rf.e9f3d4186671933751b0c431cc1bfb0c.txt
#  extracting: valid/labels/PennPed00073_png.rf.3aef0525fbe7935e6645332159b8dda7.txt
#  extracting: valid/labels/PennPed00076_png.rf.763a7755bc6ebe25a500ae3feedf5956.txt
#  extracting: valid/labels/PennPed00077_png.rf.bd8ff1cd103edb4bab0dd9c32406c1ad.txt
#  extracting: valid/labels/PennPed00077_png.rf.df4fd05a84115a25a619f47f3bcd1b0c.txt
#  extracting: valid/labels/PennPed00088_png.rf.be7892bcd0757c16486554e571e1d4c5.txt
#  extracting: valid/labels/PennPed00090_png.rf.b35d52780091e9ab6b5472b4fec6cfa2.txt

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17521, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 17521 (delta 9), reused 0 (delta 0), pack-reused 17497 (from 4)
# Receiving objects: 100% (17521/17521), 16.66 MiB | 19.86 MiB/s, done.
# Resolving deltas: 100% (12001/12001), done.
# /content/yolov5
# Requirement already satisfied: gitpython>=3.1.30 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 5)) (3.1.45)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (3.10.0)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (2.0.2)
# Requirement already satisfied: opencv-python>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 8)) (4.12.0.88)
# Requirement already satisfied: pillow>=10.3.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 9)) (11.3.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 10)) (5.9.5)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 11)) (6.0.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 12)) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 13)) (1.16.0)
# Collecting thop>=0.1.1 (from -r requirements.txt (line 14))
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 15)) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 16)) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 17)) (4.67.1)
# Collecting ultralytics>=8.2.64 (from -r requirements.txt (line 18))
#   Downloading ultralytics-8.3.173-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 27)) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 28)) (0.13.2)
# Requirement already satisfied: setuptools>=70.0.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 42)) (75.2.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython>=3.1.30->-r requirements.txt (line 5)) (4.0.12)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (2025.7.14)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->-r requirements.txt (line 15))
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->-r requirements.txt (line 15)) (1.3.0)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics>=8.2.64->-r requirements.txt (line 18)) (9.0.0)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics>=8.2.64->-r requirements.txt (line 18))
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2025.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements.txt (line 5)) (5.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->-r requirements.txt (line 15)) (3.0.2)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 141.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 106.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 67.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 20.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 113.0 MB/s eta 0:00:00
# Downloading ultralytics-8.3.173-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 73.4 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 thop-0.1.1.post2209072238 ultralytics-8.3.173 ultralytics-thop-2.0.14

# %%
import cv2
import numpy as np
from pathlib import Path
from yolov5.utils.general import non_max_suppression, xywh2xyxy
import matplotlib.pyplot as plt
import torch
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import torch
from models.experimental import attempt_load

# Load trained model
model = attempt_load('/content/roadtarget.pt')
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs

# %%
import torch
import numpy as np
from collections import defaultdict

def iou(box1, box2):
    """Compute IoU between two boxes: [x1, y1, x2, y2]"""
    x1 = torch.max(box1[0], box2[0])
    y1 = torch.max(box1[1], box2[1])
    x2 = torch.min(box1[2], box2[2])
    y2 = torch.min(box1[3], box2[3])

    inter_area = torch.clamp(x2 - x1, min=0) * torch.clamp(y2 - y1, min=0)
    box1_area = (box1[2] - box1[0]) * (box1[3] - box1[1])
    box2_area = (box2[2] - box2[0]) * (box2[3] - box2[1])
    return inter_area / (box1_area + box2_area - inter_area + 1e-6)

def compute_ap(recall, precision):
    """Compute interpolated Average Precision (AP) using trapezoidal rule"""
    mrec = torch.cat([torch.tensor([0.]), recall, torch.tensor([1.])])
    mpre = torch.cat([torch.tensor([0.]), precision, torch.tensor([0.])])

    for i in range(mpre.numel() - 1, 0, -1):
        mpre[i - 1] = torch.max(mpre[i - 1], mpre[i])

    i = (mrec[1:] != mrec[:-1]).nonzero(as_tuple=False).squeeze()
    return torch.sum((mrec[i + 1] - mrec[i]) * mpre[i + 1])


def evaluate_detections(preds, targets, iou_thresh=0.5):
    preds = torch.tensor(preds)
    targets = torch.tensor(targets)

    # Group ground truths and predictions per class
    gt_by_class = defaultdict(list)
    pred_by_class = defaultdict(list)

    for t in targets:
        if isinstance(t, (torch.Tensor, list)) and len(t) == 1:
            t = t[0]
        if isinstance(t, torch.Tensor):
            t = t.view(-1).tolist()

        img_id, cls, x1, y1, x2, y2 = t
        img_id = int(img_id)
        cls = int(cls)
        box = torch.tensor([x1, y1, x2, y2]).float()
        gt_by_class[cls].append((img_id, box))

    for p in preds:
        if isinstance(p, (torch.Tensor, list)) and len(p) == 1:
            p = p[0]
        if isinstance(p, torch.Tensor):
            p = p.view(-1).tolist()

        img_id, cls, conf, x1, y1, x2, y2 = p
        img_id = int(img_id)
        cls = int(cls)
        conf = float(conf)
        box = torch.tensor([x1, y1, x2, y2]).float()
        pred_by_class[cls].append((img_id, conf, box))



    results = {}
    aps = []

    for cls in sorted(gt_by_class.keys()):
        gt = gt_by_class[cls]
        pred = sorted(pred_by_class.get(cls, []), key=lambda x: -x[1])  # sort by conf

        gt_used = defaultdict(set)  # img_id -> set of matched GT indices
        tp = torch.zeros(len(pred))
        fp = torch.zeros(len(pred))

        for i, (img_id, conf, pred_box) in enumerate(pred):
            gts = [b for j, b in enumerate(gt) if b[0] == img_id]
            ious = [iou(pred_box, b[1]) for b in gts] if gts else []

            if ious and max(ious) >= iou_thresh:
                max_iou_idx = int(torch.argmax(torch.tensor(ious)))
                if max_iou_idx not in gt_used[img_id]:
                    tp[i] = 1
                    gt_used[img_id].add(max_iou_idx)
                else:
                    fp[i] = 1
            else:
                fp[i] = 1

        tp_cum = torch.cumsum(tp, dim=0)
        fp_cum = torch.cumsum(fp, dim=0)
        recall = tp_cum / (len(gt) + 1e-6)
        precision = tp_cum / (tp_cum + fp_cum + 1e-6)

        ap = compute_ap(recall, precision)
        aps.append(ap)

        results[cls] = {
            "precision": precision[-1].item() if len(precision) else 0.0,
            "recall": recall[-1].item() if len(recall) else 0.0,
            "f1": (2 * precision[-1] * recall[-1] / (precision[-1] + recall[-1] + 1e-6)).item() if len(precision) else 0.0,
            "ap50": ap.item()
        }

    mAP = torch.tensor(aps).mean().item() if aps else 0.0
    return results, mAP

# %%
def load_image(path, img_size=640):
    img0 = cv2.imread(str(path))  # BGR
    img = cv2.resize(img0, (img_size, img_size))
    img = img[:, :, ::-1].transpose(2, 0, 1)  # BGR to RGB, to 3xHxW
    img = np.ascontiguousarray(img)
    img = torch.from_numpy(img).float()
    img /= 255.0
    if img.ndimension() == 3:
        img = img.unsqueeze(0)
    return img.to(device), img0

image_dir = Path('/content/test/images')
label_dir = Path('/content/test/labels')

def scale_coords(img1_shape, coords, img0_shape, ratio_pad=None):
      """Rescale coords (xyxy) from img1_shape to img0_shape"""
      if ratio_pad is None:
          # Calculate gain and pad
          gain = min(img1_shape[0] / img0_shape[0], img1_shape[1] / img0_shape[1])  # gain = old / new
          pad = (img1_shape[1] - img0_shape[1] * gain) / 2, (img1_shape[0] - img0_shape[0] * gain) / 2  # x, y
      else:
          gain = ratio_pad[0]
          pad = ratio_pad[1]

      coords[:, [0, 2]] -= pad[0]  # x padding
      coords[:, [1, 3]] -= pad[1]  # y padding
      coords[:, :4] /= gain
      coords[:, :4] = coords[:, :4].clamp(min=0)
      return coords


def pedict(img_tensor, img0, img_path, image_id):
    model.eval()
    preds_for_img = []
    targets_for_img = []

    with torch.no_grad():
        pred = model(img_tensor)[0]  # Assuming model returns (pred, ...)
        pred = non_max_suppression(pred, conf_thres=0.25, iou_thres=0.5)[0]

        if pred is not None and len(pred):
            pred[:, :4] = scale_coords(img_tensor.shape[2:], pred[:, :4], img0.shape).round()
            for *box, conf, cls in pred.tolist():
                preds_for_img.append([image_id, int(cls), conf, *box])

    # Load ground truth
    label_path = label_dir / (img_path.stem + '.txt')
    h, w = img0.shape[:2]
    if label_path.exists():
        with open(label_path, 'r') as f:
            for line in f:
                cls, xc, yc, bw, bh = map(float, line.strip().split())
                x1 = (xc - bw / 2) * w
                y1 = (yc - bh / 2) * h
                x2 = (xc + bw / 2) * w
                y2 = (yc + bh / 2) * h
                targets_for_img.append([image_id, int(cls), x1, y1, x2, y2])

    return preds_for_img, targets_for_img

# %%
from skimage.feature import local_binary_pattern
def er(image):
  grad_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=3)
  grad_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=3)
  grad_mag = np.sqrt(grad_x**2 + grad_y**2)
  return np.mean(grad_mag)

def obj_found(image):
  image = (image * 255).astype(np.uint8)
  params = cv2.SimpleBlobDetector_Params()
  params.filterByArea = True
  params.minArea = 10  # Minimum blob size (adjust for small objects)
  params.maxArea = 1000
  detector = cv2.SimpleBlobDetector_create(params)
  keypoints = detector.detect(image)
  return len(keypoints)

def ed(image):
    local_var = cv2.Laplacian(image, cv2.CV_32F).var()#The Laplacian operator highlights regions of rapid intensity change (edges),High variance = many strong edges = likely not occluded
    return local_var / (np.mean(image)+ 1e-6)

def is_blurry(image):
    return cv2.Laplacian(image, cv2.CV_64F).var()

def brightness(img):
    brightness = np.mean(img)
    return brightness

def complexity(image):
  image = np.array(image).reshape(len(image), -1)
  lbp = local_binary_pattern(image, 8, 1, method="uniform")#greater the no. more complex the image
  hist, _ = np.histogram(lbp, bins=8+2, range=(0, 8+2))
  hist = hist.astype(np.float32) / hist.sum()
  grad_mag=-np.sum(hist * np.log(hist + 1e-6))
  return grad_mag

# %% [markdown]
# # control

# %%
# names: ['Pedestrians']

# %%
image_id = 0
count=0
all_preds = []
all_targets = []
for img_path in image_dir.glob('*.jpg'):
        img_tensor, img0 = load_image(img_path)  # Should return a tensor [1,3,H,W] and original image
        preds, targets = pedict(img_tensor, img0, img_path, image_id)
        all_preds.append(preds)
        all_targets.append(targets)
        count+=1
        image_id += 1

all_preds_flat = [item for sublist in all_preds for item in sublist]
all_targets_flat = [item for sublist in all_targets for item in sublist]

# Clean predictions
all_preds_clean = [p for p in all_preds_flat if len(p) == 7]
all_targets_clean = [t for t in all_targets_flat if len(t) == 6]

results, mAP50 = evaluate_detections(all_preds_clean, all_targets_clean, iou_thresh=0.6)

for cls, metrics in results.items():
    print(f"Class {cls}:")
    print(f"  Precision: {metrics['precision']:.4f}")
    print(f"  Recall:    {metrics['recall']:.4f}")
    print(f"  F1 Score:  {metrics['f1']:.4f}")
    print(f"  AP@0.5:    {metrics['ap50']:.4f}")
print(f"  count:     {count}")
print(f"\nMean AP@0.5 (mAP50): {mAP50:.4f}")
# Out:
# Class 0:
#   Precision: 0.6667
#   Recall:    0.2500
#   F1 Score:  0.3636
#   AP@0.5:    0.2378
#   count:     23
#
# Mean AP@0.5 (mAP50): 0.2378

# %% [markdown]
# #ed

# %%
image_id = 0
count=0
all_preds = []
all_targets = []
for img_path in image_dir.glob('*.jpg'):
    img = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (28,28))
    img = np.array(img, dtype=np.float32) / 255.0
    img = img.flatten()
    if ed(img) < 0.64 :
        img_tensor, img0 = load_image(img_path)  # Should return a tensor [1,3,H,W] and original image
        preds, targets = pedict(img_tensor, img0, img_path, image_id)
        all_preds.append(preds)
        all_targets.append(targets)
        count+=1
    image_id += 1

all_preds_flat = [item for sublist in all_preds for item in sublist]
all_targets_flat = [item for sublist in all_targets for item in sublist]

# Clean predictions
all_preds_clean = [p for p in all_preds_flat if len(p) == 7]
all_targets_clean = [t for t in all_targets_flat if len(t) == 6]

results, mAP50 = evaluate_detections(all_preds_clean, all_targets_clean, iou_thresh=0.6)

for cls, metrics in results.items():
    print(f"Class {cls}:")
    print(f"  Precision: {metrics['precision']:.4f}")
    print(f"  Recall:    {metrics['recall']:.4f}")
    print(f"  F1 Score:  {metrics['f1']:.4f}")
    print(f"  AP@0.5:    {metrics['ap50']:.4f}")
print(f"  count:     {count}")
print(f"\nMean AP@0.5 (mAP50): {mAP50:.4f}")
# Out:
# Class 0:
#   Precision: 0.6667
#   Recall:    0.2500
#   F1 Score:  0.3636
#   AP@0.5:    0.2378
#   count:     23
#
# Mean AP@0.5 (mAP50): 0.2378

# %%
image_id = 0
count=0
all_preds = []
all_targets = []
for img_path in image_dir.glob('*.jpg'):
    img = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (28,28))
    img = np.array(img, dtype=np.float32) / 255.0
    img = img.flatten()
    if ed(img) > 0.64:
        img_tensor, img0 = load_image(img_path)  # Should return a tensor [1,3,H,W] and original image
        preds, targets = pedict(img_tensor, img0, img_path, image_id)
        all_preds.append(preds)
        all_targets.append(targets)
        count+=1
    image_id += 1

all_preds_flat = [item for sublist in all_preds for item in sublist]
all_targets_flat = [item for sublist in all_targets for item in sublist]

# Clean predictions
all_preds_clean = [p for p in all_preds_flat if len(p) == 7]
all_targets_clean = [t for t in all_targets_flat if len(t) == 6]

results, mAP50 = evaluate_detections(all_preds_clean, all_targets_clean, iou_thresh=0.6)

for cls, metrics in results.items():
    print(f"Class {cls}:")
    print(f"  Precision: {metrics['precision']:.4f}")
    print(f"  Recall:    {metrics['recall']:.4f}")
    print(f"  F1 Score:  {metrics['f1']:.4f}")
    print(f"  AP@0.5:    {metrics['ap50']:.4f}")
print(f"  count:     {count}")
print(f"\nMean AP@0.5 (mAP50): {mAP50:.4f}")
# Out:
#   count:     0
#
# Mean AP@0.5 (mAP50): 0.0000

# %% [markdown]
# # complexity

# %%
image_id = 0
count=0
all_preds = []
all_targets = []
for img_path in image_dir.glob('*.jpg'):
    img = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (28,28))
    img = np.array(img, dtype=np.float32) / 255.0
    img = img.flatten()
    if complexity(img) > 1.23 and complexity(img) < 1.39:
        img_tensor, img0 = load_image(img_path)  # Should return a tensor [1,3,H,W] and original image
        preds, targets = pedict(img_tensor, img0, img_path, image_id)
        all_preds.append(preds)
        all_targets.append(targets)
        count+=1
    image_id += 1

all_preds_flat = [item for sublist in all_preds for item in sublist]
all_targets_flat = [item for sublist in all_targets for item in sublist]

# Clean predictions
all_preds_clean = [p for p in all_preds_flat if len(p) == 7]
all_targets_clean = [t for t in all_targets_flat if len(t) == 6]

results, mAP50 = evaluate_detections(all_preds_clean, all_targets_clean, iou_thresh=0.6)

for cls, metrics in results.items():
    print(f"Class {cls}:")
    print(f"  Precision: {metrics['precision']:.4f}")
    print(f"  Recall:    {metrics['recall']:.4f}")
    print(f"  F1 Score:  {metrics['f1']:.4f}")
    print(f"  AP@0.5:    {metrics['ap50']:.4f}")
print(f"  count:     {count}")
print(f"\nMean AP@0.5 (mAP50): {mAP50:.4f}")
# Out:
#   count:     0
#
# Mean AP@0.5 (mAP50): 0.0000

# %%
image_id = 0
count=0
all_preds = []
all_targets = []
for img_path in image_dir.glob('*.jpg'):
    img = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (28,28))
    img = np.array(img, dtype=np.float32) / 255.0
    img = img.flatten()
    if complexity(img) < 1.23 or complexity(img) > 1.39:
        img_tensor, img0 = load_image(img_path)  # Should return a tensor [1,3,H,W] and original image
        preds, targets = pedict(img_tensor, img0, img_path, image_id)
        all_preds.append(preds)
        all_targets.append(targets)
        count+=1
    image_id += 1

all_preds_flat = [item for sublist in all_preds for item in sublist]
all_targets_flat = [item for sublist in all_targets for item in sublist]

# Clean predictions
all_preds_clean = [p for p in all_preds_flat if len(p) == 7]
all_targets_clean = [t for t in all_targets_flat if len(t) == 6]

results, mAP50 = evaluate_detections(all_preds_clean, all_targets_clean, iou_thresh=0.6)

for cls, metrics in results.items():
    print(f"Class {cls}:")
    print(f"  Precision: {metrics['precision']:.4f}")
    print(f"  Recall:    {metrics['recall']:.4f}")
    print(f"  F1 Score:  {metrics['f1']:.4f}")
    print(f"  AP@0.5:    {metrics['ap50']:.4f}")
print(f"  count:     {count}")
print(f"\nMean AP@0.5 (mAP50): {mAP50:.4f}")
# Out:
# Class 0:
#   Precision: 0.6667
#   Recall:    0.2500
#   F1 Score:  0.3636
#   AP@0.5:    0.2378
#   count:     23
#
# Mean AP@0.5 (mAP50): 0.2378

# %% [markdown]
# # brightness

# %%
image_id = 0
count=0
all_preds = []
all_targets = []
for img_path in image_dir.glob('*.jpg'):
    img = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (28,28))
    img = np.array(img, dtype=np.float32) / 255.0
    img = img.flatten()
    if brightness(img) < 0.27 or brightness(img) > 0.53:
        img_tensor, img0 = load_image(img_path)  # Should return a tensor [1,3,H,W] and original image
        preds, targets = pedict(img_tensor, img0, img_path, image_id)
        all_preds.append(preds)
        all_targets.append(targets)
        count+=1
    image_id += 1

all_preds_flat = [item for sublist in all_preds for item in sublist]
all_targets_flat = [item for sublist in all_targets for item in sublist]

# Clean predictions
all_preds_clean = [p for p in all_preds_flat if len(p) == 7]
all_targets_clean = [t for t in all_targets_flat if len(t) == 6]

results, mAP50 = evaluate_detections(all_preds_clean, all_targets_clean, iou_thresh=0.6)

for cls, metrics in results.items():
    print(f"Class {cls}:")
    print(f"  Precision: {metrics['precision']:.4f}")
    print(f"  Recall:    {metrics['recall']:.4f}")
    print(f"  F1 Score:  {metrics['f1']:.4f}")
    print(f"  AP@0.5:    {metrics['ap50']:.4f}")
print(f"  count:     {count}")
print(f"\nMean AP@0.5 (mAP50): {mAP50:.4f}")
# Out:
# Class 0:
#   Precision: 0.0000
#   Recall:    0.0000
#   F1 Score:  0.0000
#   AP@0.5:    0.0000
#   count:     2
#
# Mean AP@0.5 (mAP50): 0.0000

# %%
image_id = 0
count=0
all_preds = []
all_targets = []
for img_path in image_dir.glob('*.jpg'):
    img = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (28,28))
    img = np.array(img, dtype=np.float32) / 255.0
    img = img.flatten()
    if brightness(img) > 0.27 and brightness(img) < 0.53:
        img_tensor, img0 = load_image(img_path)  # Should return a tensor [1,3,H,W] and original image
        preds, targets = pedict(img_tensor, img0, img_path, image_id)
        all_preds.append(preds)
        all_targets.append(targets)
        count+=1
    image_id += 1

all_preds_flat = [item for sublist in all_preds for item in sublist]
all_targets_flat = [item for sublist in all_targets for item in sublist]

# Clean predictions
all_preds_clean = [p for p in all_preds_flat if len(p) == 7]
all_targets_clean = [t for t in all_targets_flat if len(t) == 6]

results, mAP50 = evaluate_detections(all_preds_clean, all_targets_clean, iou_thresh=0.6)

for cls, metrics in results.items():
    print(f"Class {cls}:")
    print(f"  Precision: {metrics['precision']:.4f}")
    print(f"  Recall:    {metrics['recall']:.4f}")
    print(f"  F1 Score:  {metrics['f1']:.4f}")
    print(f"  AP@0.5:    {metrics['ap50']:.4f}")
print(f"  count:     {count}")
print(f"\nMean AP@0.5 (mAP50): {mAP50:.4f}")
# Out:
# Class 0:
#   Precision: 0.6667
#   Recall:    0.2791
#   F1 Score:  0.3934
#   AP@0.5:    0.2655
#   count:     21
#
# Mean AP@0.5 (mAP50): 0.2655
